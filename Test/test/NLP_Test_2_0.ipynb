# %% [markdown]
# # STORY

# %% [markdown]
#  Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice. From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains. He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often oppressing the local population, which deeply disturbed him and fueled his desire to establish Swarajya, or self-rule for the Marathas. By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy. As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India. In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan. Shivaji’s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolstered his legend. He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces. In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos. Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance. Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites. His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time. Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses. As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India. Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death. His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endures in the form of the Maratha Empire’s contributions to India’s history and culture.

# %% [markdown]
# # Questions Using SpaCy, NLTK, and TextBlob
#
#
# 1- Tokenization
#
# Use NLTK to tokenize the text into words.
#
#
# Tokenize the text into sentences using spaCy.
#
#
# 2- Named Entity Recognition (NER)
#
# Use spaCy to extract all named entities in the text.
#
#
# Identify and count all locations mentioned in the text using spaCy's NER.
#
#
# 3- Part of Speech (POS) Tagging
#
# Use TextBlob to tag the parts of speech for each word.
#
# Extract and list all nouns in the text using spaCy.
#
#
# 4- Stop Words Removal
#
# Use NLTK to remove stop words from the text and display the cleaned text.
#
#
# Use spaCy to remove stop words, then join and display the text without stop words.
#
#
# 5- Lemmatization
#
# Use spaCy to lemmatize each word in the text.
#
#
# Use NLTK to lemmatize only the verbs in the text.
#
# 6- Sentiment Analysis
#
# Use TextBlob to perform sentiment analysis on the entire text.
#
#
# Divide the text into sentences and analyze the sentiment of each sentence with TextBlob.
#
#
# 7- N-Grams
#
# Generate bigrams (two-word combinations) using NLTK.
#
#
# Generate trigrams (three-word combinations) using TextBlob.
#
#
# 8- Frequency Distribution
#
# Use NLTK to compute the frequency distribution of words in the text.
#
# Find the 5 most common nouns in the text using spaCy.
#
#
# 9- Dependency Parsing
#
# Extract and display dependency parse information for each sentence using spaCy.
#
# Visualize the dependency tree of the first sentence using spaCy’s displacy tool.
#
#
# 10- Phrase Matching
#
# Identify occurrences of the phrase "Maratha Empire" using spaCy's PhraseMatcher.
#
#
# Use spaCy’s Matcher to find patterns where Shivaji Maharaj is mentioned along with actions (verbs).
#
#
# 11- Sentence Similarity
#
#
# Calculate the similarity between the first two sentences of the text using spaCy.
#
#
# Use TextBlob to compute the similarity between sentences mentioning "Shivaji" and "Mughal Empire."
#
#
# 12- Translation
#
#
# Translate the first paragraph into Hindi using TextBlob.
#
#
# Translate the phrase "Hindavi Swarajya" into French using TextBlob.
#
#
# 13- Keyword Extraction
#
#
# Extract keywords using NLTK’s frequency distribution (common nouns and verbs).
#
#
# Use spaCy to identify and list unique keywords from the text (filter out stop words).
#
#
# 14- Coreference Resolution
#
#
#
# Use spaCy's neuralcoref extension to resolve pronouns in the text.
#
#
# Identify any instances where pronouns can be replaced with entity names for better clarity.
#
#
# 15- Sentiment Polarity Distribution
#
# Calculate and plot the sentiment polarity distribution for each sentence in the text using TextBlob.
#
#
# Identify and display the most positive and most negative sentences based on sentiment scores.
#
#
# 16- Extract Dates and Events
#
#
# Identify all dates mentioned in the text using spaCy.
#
# Use regex to find sentences related to events happening in specific years (e.g., 1674 or 1680).
#
#
# 17- Synonyms and Antonyms
#
# Use TextBlob's WordNet to find synonyms for "bravery," "justice," and "valor."
#
#
# Find antonyms of "oppression" and "invasion" using NLTK’s WordNet.
#
#
# 18- Spelling Correction
#
# Introduce 5 spelling errors in the text and use TextBlob to correct them.
#
#
# Identify words with potential spelling errors using TextBlob.
#
#
# 19- Extract Subject-Verb-Object Triples
#
# Use spaCy to extract subject-verb-object triples from the sentences.
#
#
# Identify and list sentences where "Shivaji" is the subject and a verb follows, using dependency parsing.
#
# 20- Create a Summary
#
# Summarize the text using TextBlob by extracting key sentences.
#
#
# Generate a summary using NLTK’s summarize function on cleaned text.

# %%
# !pip install nltk spacy
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.12.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.3)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)

# %%
#1- Tokenization

#Use NLTK to tokenize the text into words.

#Tokenize the text into sentences using spaCy.
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
import spacy

# %%
import nltk
nltk.download('punkt')  # For word tokenization

import spacy
nlp = spacy.load('en_core_web_sm')  # For sentence tokenization
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
text = "Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice. From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains. He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often oppressing the local population, which deeply disturbed him and fueled his desire to establish Swarajya, or self-rule for the Marathas. By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy. As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India. In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan. Shivaji’s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolstered his legend. He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces. In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos. Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance. Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites. His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time. Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses. As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India. Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death. His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endures in the form of the Maratha Empire’s contributions to India’s history and culture."

# Word Tokenization using NLTK
word_tokens = nltk.word_tokenize(text)
print("Word Tokens:", word_tokens)

# Sentence Tokenization using spaCy
doc = nlp(text)
sentence_tokens = [sent.text for sent in doc.sents]
print("Sentence Tokens:", sentence_tokens)
# Out:
# Word Tokens: ['Chhatrapati', 'Shivaji', 'Maharaj', 'was', 'born', 'on', 'February', '19', ',', '1630', ',', 'at', 'Shivneri', 'Fort', 'in', 'Maharashtra', ',', 'to', 'Shahaji', 'Bhonsle', ',', 'a', 'Maratha', 'general', ',', 'and', 'Jijabai', ',', 'who', 'deeply', 'influenced', 'Shivaji', 'with', 'her', 'teachings', 'on', 'dharma', ',', 'bravery', ',', 'and', 'justice', '.', 'From', 'an', 'early', 'age', ',', 'Shivaji', 'exhibited', 'remarkable', 'leadership', 'qualities', ',', 'forming', 'a', 'group', 'of', 'loyal', 'followers', 'and', 'honing', 'his', 'military', 'skills', 'in', 'the', 'rugged', 'terrain', 'of', 'the', 'Sahyadri', 'mountains', '.', 'He', 'grew', 'up', 'during', 'a', 'time', 'when', 'the', 'Mughal', 'Empire', 'under', 'Emperor', 'Aurangzeb', 'and', 'the', 'Deccan', 'Sultanates', 'were', 'vying', 'for', 'control', ',', 'often', 'oppressing', 'the', 'local', 'population', ',', 'which', 'deeply', 'disturbed', 'him', 'and', 'fueled', 'his', 'desire', 'to', 'establish', 'Swarajya', ',', 'or', 'self-rule', 'for', 'the', 'Marathas', '.', 'By', 'the', 'age', 'of', '16', ',', 'Shivaji', 'had', 'captured', 'his', 'first', 'fort', ',', 'Torna', ',', 'using', 'guerrilla', 'warfare', 'tactics', 'that', 'would', 'later', 'become', 'a', 'hallmark', 'of', 'his', 'military', 'strategy', '.', 'As', 'his', 'conquests', 'grew', ',', 'he', 'formed', 'alliances', 'with', 'local', 'leaders', ',', 'securing', 'key', 'forts', 'like', 'Raigad', ',', 'Kondana', ',', 'and', 'Purandar', ',', 'establishing', 'a', 'solid', 'territorial', 'base', 'in', 'western', 'India', '.', 'In', '1659', ',', 'he', 'faced', 'and', 'defeated', 'Afzal', 'Khan', ',', 'a', 'prominent', 'general', 'of', 'the', 'Bijapur', 'Sultanate', ',', 'solidifying', 'his', 'reputation', 'as', 'a', 'brave', 'and', 'tactical', 'leader', ';', 'this', 'victory', 'was', 'crucial', 'in', 'establishing', 'his', 'control', 'over', 'much', 'of', 'the', 'Deccan', '.', 'Shivaji', '’', 's', 'raids', 'on', 'Mughal', 'territories', 'and', 'his', 'escape', 'from', 'the', 'clutches', 'of', 'Aurangzeb', 'in', 'Agra', 'in', '1666', 'further', 'bolstered', 'his', 'legend', '.', 'He', 'realized', 'that', 'a', 'powerful', 'navy', 'was', 'crucial', 'to', 'safeguard', 'his', 'territories', 'from', 'foreign', 'invasions', ',', 'leading', 'him', 'to', 'develop', 'one', 'of', 'the', 'earliest', 'organized', 'naval', 'forces', 'in', 'India', ',', 'allowing', 'him', 'to', 'secure', 'coastal', 'areas', 'against', 'Portuguese', ',', 'British', ',', 'and', 'Siddis', 'forces', '.', 'In', '1674', ',', 'he', 'formally', 'crowned', 'himself', 'as', 'Chhatrapati', 'at', 'Raigad', 'Fort', ',', 'declaring', 'his', 'independence', 'and', 'establishing', 'the', 'Maratha', 'Empire', ',', 'thus', 'becoming', 'the', 'first', 'king', 'to', 'establish', 'Hindavi', 'Swarajya', ',', 'an', 'autonomous', 'kingdom', 'with', 'a', 'structured', 'administrative', 'framework', 'rooted', 'in', 'Indian', 'ethos', '.', 'Shivaji', '’', 's', 'administrative', 'system', 'was', 'highly', 'efficient', ',', 'and', 'he', 'emphasized', 'the', 'welfare', 'of', 'his', 'people', ',', 'setting', 'up', 'systems', 'to', 'reduce', 'corruption', 'and', 'create', 'a', 'fair', 'tax', 'structure', ';', 'his', 'Ashta', 'Pradhan', '(', 'Council', 'of', 'Eight', 'Ministers', ')', 'included', 'departments', 'for', 'finance', ',', 'internal', 'affairs', ',', 'foreign', 'policy', ',', 'and', 'military', 'to', 'ensure', 'smooth', 'governance', '.', 'Shivaji', 'showed', 'a', 'progressive', 'approach', 'towards', 'governance', ',', 'promoting', 'religious', 'tolerance', 'and', 'respecting', 'the', 'diversity', 'within', 'his', 'empire', ',', 'even', 'appointing', 'Muslims', 'to', 'key', 'positions', 'in', 'his', 'administration', 'and', 'banning', 'the', 'harassment', 'of', 'women', 'and', 'looting', 'of', 'religious', 'sites', '.', 'His', 'respect', 'for', 'women', 'and', 'his', 'advocacy', 'for', 'justice', 'inspired', 'trust', 'and', 'loyalty', 'among' ...
# Sentence Tokens: ['Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice.', 'From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains.', 'He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often oppressing the local population, which deeply disturbed him and fueled his desire to establish Swarajya, or self-rule for the Marathas.', 'By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy.', 'As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India.', 'In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan.', 'Shivaji’s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolstered his legend.', 'He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces.', 'In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos.', 'Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance.', 'Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites.', 'His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time.', 'Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses.', 'As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India.', 'Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death.', 'His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endures in the form of the Maratha Empire’s contributions to India’s history and culture.']

# %%
import spacy
from collections import Counter

nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

entities = [(ent.text, ent.label_) for ent in doc.ents]

locations = [ent.text for ent in doc.ents if ent.label_ == "GPE"]
location_counts = Counter(locations)

print("Named Entities:", entities)
print("\nLocations and their counts:", location_counts)
# Out:
# Named Entities: [('Chhatrapati Shivaji Maharaj', 'PERSON'), ('February 19, 1630', 'DATE'), ('Shivneri Fort', 'FAC'), ('Maharashtra', 'GPE'), ('Shahaji Bhonsle', 'ORG'), ('Maratha', 'GPE'), ('Jijabai', 'GPE'), ('Shivaji', 'PERSON'), ('Shivaji', 'PERSON'), ('Sahyadri', 'LOC'), ('Swarajya', 'ORG'), ('Marathas', 'PERSON'), ('the age of 16', 'DATE'), ('Shivaji', 'PERSON'), ('first', 'ORDINAL'), ('Torna', 'GPE'), ('Raigad', 'GPE'), ('Kondana', 'PERSON'), ('Purandar', 'ORG'), ('India', 'GPE'), ('1659', 'DATE'), ('Afzal Khan', 'PERSON'), ('the Bijapur Sultanate', 'GPE'), ('Deccan', 'PRODUCT'), ('Shivaji', 'PERSON'), ('Agra', 'ORG'), ('1666', 'DATE'), ('India', 'GPE'), ('Portuguese', 'NORP'), ('British', 'NORP'), ('Siddis', 'NORP'), ('1674', 'DATE'), ('Raigad Fort', 'FAC'), ('the Maratha Empire', 'LOC'), ('first', 'ORDINAL'), ('Hindavi Swarajya', 'PERSON'), ('Indian', 'NORP'), ('Shivaji', 'PERSON'), ('Ashta Pradhan (Council of Eight Ministers', 'ORG'), ('Shivaji', 'PERSON'), ('Muslims', 'NORP'), ('Shivaji Maharaj', 'PERSON'), ('Ganimi Kava', 'PERSON'), ('the Maratha Empire', 'ORG'), ('Maharashtra', 'ORG'), ('Maratha', 'PERSON'), ('India', 'GPE'), ('April 3, 1680', 'DATE'), ('Raigad Fort', 'FAC'), ('millions', 'CARDINAL'), ('the Maratha Empire’s', 'LOC'), ('India', 'GPE')]
#
# Locations and their counts: Counter({'India': 4, 'Maharashtra': 1, 'Maratha': 1, 'Jijabai': 1, 'Torna': 1, 'Raigad': 1, 'the Bijapur Sultanate': 1})

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
from textblob import TextBlob
import spacy
# Part of Speech tagging using TextBlob
blob = TextBlob(text)
pos_tags = blob.tags

nlp = spacy.load("en_core_web_sm")

# Process the text with spaCy
doc = nlp(text)

# Extract all nouns using spaCy
nouns = [token.text for token in doc if token.pos_ == "NOUN"]

print("Part of Speech Tags:", pos_tags)
print("\nNouns:", nouns)
# Out:
# Part of Speech Tags: [('Chhatrapati', 'NNP'), ('Shivaji', 'NNP'), ('Maharaj', 'NNP'), ('was', 'VBD'), ('born', 'VBN'), ('on', 'IN'), ('February', 'NNP'), ('19', 'CD'), ('1630', 'CD'), ('at', 'IN'), ('Shivneri', 'NNP'), ('Fort', 'NNP'), ('in', 'IN'), ('Maharashtra', 'NNP'), ('to', 'TO'), ('Shahaji', 'NNP'), ('Bhonsle', 'NNP'), ('a', 'DT'), ('Maratha', 'NNP'), ('general', 'NN'), ('and', 'CC'), ('Jijabai', 'NNP'), ('who', 'WP'), ('deeply', 'RB'), ('influenced', 'VBD'), ('Shivaji', 'NNP'), ('with', 'IN'), ('her', 'PRP$'), ('teachings', 'NNS'), ('on', 'IN'), ('dharma', 'NN'), ('bravery', 'NN'), ('and', 'CC'), ('justice', 'NN'), ('From', 'IN'), ('an', 'DT'), ('early', 'JJ'), ('age', 'NN'), ('Shivaji', 'NNP'), ('exhibited', 'VBD'), ('remarkable', 'JJ'), ('leadership', 'NN'), ('qualities', 'NNS'), ('forming', 'VBG'), ('a', 'DT'), ('group', 'NN'), ('of', 'IN'), ('loyal', 'JJ'), ('followers', 'NNS'), ('and', 'CC'), ('honing', 'VBG'), ('his', 'PRP$'), ('military', 'JJ'), ('skills', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('rugged', 'JJ'), ('terrain', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Sahyadri', 'NNP'), ('mountains', 'NNS'), ('He', 'PRP'), ('grew', 'VBD'), ('up', 'RP'), ('during', 'IN'), ('a', 'DT'), ('time', 'NN'), ('when', 'WRB'), ('the', 'DT'), ('Mughal', 'NNP'), ('Empire', 'NNP'), ('under', 'IN'), ('Emperor', 'NNP'), ('Aurangzeb', 'NNP'), ('and', 'CC'), ('the', 'DT'), ('Deccan', 'NNP'), ('Sultanates', 'NNPS'), ('were', 'VBD'), ('vying', 'VBG'), ('for', 'IN'), ('control', 'NN'), ('often', 'RB'), ('oppressing', 'VBG'), ('the', 'DT'), ('local', 'JJ'), ('population', 'NN'), ('which', 'WDT'), ('deeply', 'RB'), ('disturbed', 'VBD'), ('him', 'PRP'), ('and', 'CC'), ('fueled', 'VBD'), ('his', 'PRP$'), ('desire', 'NN'), ('to', 'TO'), ('establish', 'VB'), ('Swarajya', 'NNP'), ('or', 'CC'), ('self-rule', 'NN'), ('for', 'IN'), ('the', 'DT'), ('Marathas', 'NNP'), ('By', 'IN'), ('the', 'DT'), ('age', 'NN'), ('of', 'IN'), ('16', 'CD'), ('Shivaji', 'NNP'), ('had', 'VBD'), ('captured', 'VBN'), ('his', 'PRP$'), ('first', 'JJ'), ('fort', 'NN'), ('Torna', 'NNP'), ('using', 'VBG'), ('guerrilla', 'NN'), ('warfare', 'NN'), ('tactics', 'NNS'), ('that', 'WDT'), ('would', 'MD'), ('later', 'RB'), ('become', 'VB'), ('a', 'DT'), ('hallmark', 'NN'), ('of', 'IN'), ('his', 'PRP$'), ('military', 'JJ'), ('strategy', 'NN'), ('As', 'IN'), ('his', 'PRP$'), ('conquests', 'NNS'), ('grew', 'VBD'), ('he', 'PRP'), ('formed', 'VBD'), ('alliances', 'NNS'), ('with', 'IN'), ('local', 'JJ'), ('leaders', 'NNS'), ('securing', 'VBG'), ('key', 'JJ'), ('forts', 'NNS'), ('like', 'IN'), ('Raigad', 'NNP'), ('Kondana', 'NNP'), ('and', 'CC'), ('Purandar', 'NNP'), ('establishing', 'VBG'), ('a', 'DT'), ('solid', 'JJ'), ('territorial', 'JJ'), ('base', 'NN'), ('in', 'IN'), ('western', 'JJ'), ('India', 'NNP'), ('In', 'IN'), ('1659', 'CD'), ('he', 'PRP'), ('faced', 'VBD'), ('and', 'CC'), ('defeated', 'VBD'), ('Afzal', 'NNP'), ('Khan', 'NNP'), ('a', 'DT'), ('prominent', 'JJ'), ('general', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Bijapur', 'NNP'), ('Sultanate', 'NNP'), ('solidifying', 'VBG'), ('his', 'PRP$'), ('reputation', 'NN'), ('as', 'IN'), ('a', 'DT'), ('brave', 'NN'), ('and', 'CC'), ('tactical', 'JJ'), ('leader', 'NN'), ('this', 'DT'), ('victory', 'NN'), ('was', 'VBD'), ('crucial', 'JJ'), ('in', 'IN'), ('establishing', 'VBG'), ('his', 'PRP$'), ('control', 'NN'), ('over', 'IN'), ('much', 'JJ'), ('of', 'IN'), ('the', 'DT'), ('Deccan', 'NNP'), ('Shivaji', 'NNP'), ('’', 'NNP'), ('s', 'JJ'), ('raids', 'NNS'), ('on', 'IN'), ('Mughal', 'NNP'), ('territories', 'NNS'), ('and', 'CC'), ('his', 'PRP$'), ('escape', 'NN'), ('from', 'IN'), ('the', 'DT'), ('clutches', 'NNS'), ('of', 'IN'), ('Aurangzeb', 'NNP'), ('in', 'IN'), ('Agra', 'NNP'), ('in', 'IN'), ('1666', 'CD'), ('further', 'RB'), ('bolstered', 'VBD'), ('his', 'PRP$'), ('legend', 'NN'), ('He', 'PRP'), ('realized', 'VBD'), ('that', 'IN'), ('a', 'DT'), ('powerful', 'JJ'), ('navy', 'NN'), ('was', 'VBD'), ('crucial', 'JJ'), ('to', 'TO'), ('safeguard', 'VB' ...
#
# Nouns: ['general', 'teachings', 'bravery', 'justice', 'age', 'leadership', 'qualities', 'group', 'followers', 'skills', 'terrain', 'mountains', 'time', 'control', 'population', 'desire', 'self', 'rule', 'age', 'fort', 'guerrilla', 'warfare', 'tactics', 'hallmark', 'strategy', 'conquests', 'alliances', 'leaders', 'forts', 'base', 'general', 'reputation', 'leader', 'victory', 'control', 'raids', 'territories', 'escape', 'clutches', 'legend', 'navy', 'territories', 'invasions', 'forces', 'areas', 'forces', 'independence', 'king', 'kingdom', 'framework', 'ethos', 'system', 'welfare', 'people', 'systems', 'corruption', 'tax', 'structure', 'departments', 'finance', 'affairs', 'policy', 'military', 'governance', 'approach', 'governance', 'tolerance', 'diversity', 'empire', 'positions', 'administration', 'harassment', 'women', 'looting', 'sites', 'respect', 'women', 'advocacy', 'justice', 'trust', 'loyalty', 'people', 'ruler', 'time', 'guerrilla', 'tactics', 'armies', 'empire', 'losses', 'fame', 'regions', 'forces', 'power', 'legacy', 'state', 'death', 'life', 'ideals', 'valor', 'respect', 'faiths', 'self', 'rule', 'millions', 'legacy', 'form', 'contributions', 'history', 'culture']

# %%
import nltk
from nltk.corpus import stopwords
import spacy

nltk.download('stopwords')
# Stop Words Removal using NLTK
nltk_stopwords = set(stopwords.words('english'))
nltk_cleaned_text = ' '.join([word for word in text.split() if word.lower() not in nltk_stopwords])

# Load the spaCy model for English
nlp = spacy.load("en_core_web_sm")

doc = nlp(text)

# Remove stop words using spaCy
spacy_cleaned_text = ' '.join([token.text for token in doc if not token.is_stop])

print("Cleaned Text using NLTK:", nltk_cleaned_text)
print("\nCleaned Text using spaCy:", spacy_cleaned_text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Cleaned Text using NLTK: Chhatrapati Shivaji Maharaj born February 19, 1630, Shivneri Fort Maharashtra, Shahaji Bhonsle, Maratha general, Jijabai, deeply influenced Shivaji teachings dharma, bravery, justice. early age, Shivaji exhibited remarkable leadership qualities, forming group loyal followers honing military skills rugged terrain Sahyadri mountains. grew time Mughal Empire Emperor Aurangzeb Deccan Sultanates vying control, often oppressing local population, deeply disturbed fueled desire establish Swarajya, self-rule Marathas. age 16, Shivaji captured first fort, Torna, using guerrilla warfare tactics would later become hallmark military strategy. conquests grew, formed alliances local leaders, securing key forts like Raigad, Kondana, Purandar, establishing solid territorial base western India. 1659, faced defeated Afzal Khan, prominent general Bijapur Sultanate, solidifying reputation brave tactical leader; victory crucial establishing control much Deccan. Shivaji’s raids Mughal territories escape clutches Aurangzeb Agra 1666 bolstered legend. realized powerful navy crucial safeguard territories foreign invasions, leading develop one earliest organized naval forces India, allowing secure coastal areas Portuguese, British, Siddis forces. 1674, formally crowned Chhatrapati Raigad Fort, declaring independence establishing Maratha Empire, thus becoming first king establish Hindavi Swarajya, autonomous kingdom structured administrative framework rooted Indian ethos. Shivaji’s administrative system highly efficient, emphasized welfare people, setting systems reduce corruption create fair tax structure; Ashta Pradhan (Council Eight Ministers) included departments finance, internal affairs, foreign policy, military ensure smooth governance. Shivaji showed progressive approach towards governance, promoting religious tolerance respecting diversity within empire, even appointing Muslims key positions administration banning harassment women looting religious sites. respect women advocacy justice inspired trust loyalty among people, making ideal ruler time. Shivaji Maharaj’s guerrilla tactics, known “Ganimi Kava,” became legendary enabled outmaneuver much larger better-equipped armies repeatedly, allowing expand empire minimizing losses. fame grew, Maratha Empire began influence regions far beyond Maharashtra, Maratha forces eventually becoming significant power across India. Shivaji passed away April 3, 1680, Raigad Fort, leaving behind powerful legacy well-organized state continued expand death. life ideals—valor, respect faiths, self-rule—continue inspire millions, legacy endures form Maratha Empire’s contributions India’s history culture.
#
# Cleaned Text using spaCy: Chhatrapati Shivaji Maharaj born February 19 , 1630 , Shivneri Fort Maharashtra , Shahaji Bhonsle , Maratha general , Jijabai , deeply influenced Shivaji teachings dharma , bravery , justice . early age , Shivaji exhibited remarkable leadership qualities , forming group loyal followers honing military skills rugged terrain Sahyadri mountains . grew time Mughal Empire Emperor Aurangzeb Deccan Sultanates vying control , oppressing local population , deeply disturbed fueled desire establish Swarajya , self - rule Marathas . age 16 , Shivaji captured fort , Torna , guerrilla warfare tactics later hallmark military strategy . conquests grew , formed alliances local leaders , securing key forts like Raigad , Kondana , Purandar , establishing solid territorial base western India . 1659 , faced defeated Afzal Khan , prominent general Bijapur Sultanate , solidifying reputation brave tactical leader ; victory crucial establishing control Deccan . Shivaji raids Mughal territories escape clutches Aurangzeb Agra 1666 bolstered legend . realized powerful navy crucial safeguard territories foreign invasions , leading develop earliest organized naval forces India , allowing secure coastal areas Portuguese , British , Siddis forces . 1674 , formally crowned Chhatrapati Raigad Fort , declaring independence establishing Maratha Empire , king establish Hindavi Swarajya , autonomous kingdom structured administrative framework rooted Indian ethos . Shivaji administrative system highly efficient , emphasized welfare people , setting systems reduce corruption create fair tax structure ; Ashta Pradhan ( Council Ministers ) included departments finance , internal affairs , foreign policy , military ensure smooth governance . Shivaji showed progressive approach governance , promoting religious tolerance respecting diversity empire , appointing Muslims key positions administration banning harassment women looting religious sites . respect women advocacy justice inspired trust loyalty people , making ideal ruler time . Shivaji Maharaj guerrilla tactics , known “ Ganimi Kava , ” legendary enabled outmaneuver larger better - equipped armies repeatedly , allowing expand empire minimizing losses . fame grew , Maratha Empire began influence regions far Maharashtra , Maratha forces eventually significant power India . Shivaji passed away April 3 , 1680 , Raigad Fort , leaving powerful legacy - organized state continued expand death . life ideals — valor , respect faiths , self - rule — continue inspire millions , legacy endures form Maratha Empire contributions India history culture .

# %%
import spacy
from nltk.stem import WordNetLemmatizer
import nltk

nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Load the spaCy model for English
nlp = spacy.load("en_core_web_sm")

# Lemmatization using spaCy
doc = nlp(text)
spacy_lemmas = [token.lemma_ for token in doc]
spacy_lemmatized_text = ' '.join(spacy_lemmas)

# Lemmatization using NLTK (only for verbs)
lemmatizer = WordNetLemmatizer()
nltk_lemmas = []
for word, pos in nltk.pos_tag(text.split()):
    if pos.startswith('VB'):
        lemmatized_word = lemmatizer.lemmatize(word, pos='v')
        nltk_lemmas.append(lemmatized_word)
    else:
        nltk_lemmas.append(word)

nltk_lemmatized_text = ' '.join(nltk_lemmas)

print("Lemmatized Text using spaCy:", spacy_lemmatized_text)
print("\nLemmatized Text using NLTK (verbs only):", nltk_lemmatized_text)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Lemmatized Text using spaCy: Chhatrapati Shivaji Maharaj be bear on February 19 , 1630 , at Shivneri Fort in Maharashtra , to Shahaji Bhonsle , a Maratha general , and Jijabai , who deeply influence Shivaji with her teaching on dharma , bravery , and justice . from an early age , Shivaji exhibit remarkable leadership quality , form a group of loyal follower and hone his military skill in the rugged terrain of the Sahyadri mountain . he grow up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates be vie for control , often oppress the local population , which deeply disturb he and fuel his desire to establish Swarajya , or self - rule for the Marathas . by the age of 16 , Shivaji have capture his first fort , Torna , use guerrilla warfare tactic that would later become a hallmark of his military strategy . as his conquest grow , he form alliance with local leader , secure key fort like Raigad , Kondana , and Purandar , establish a solid territorial base in western India . in 1659 , he face and defeat Afzal Khan , a prominent general of the Bijapur Sultanate , solidify his reputation as a brave and tactical leader ; this victory be crucial in establish his control over much of the Deccan . Shivaji ’s raid on Mughal territory and his escape from the clutch of Aurangzeb in Agra in 1666 far bolster his legend . he realize that a powerful navy be crucial to safeguard his territory from foreign invasion , lead he to develop one of the early organize naval force in India , allow he to secure coastal area against Portuguese , british , and Siddis force . in 1674 , he formally crown himself as Chhatrapati at Raigad Fort , declare his independence and establish the Maratha Empire , thus become the first king to establish Hindavi Swarajya , an autonomous kingdom with a structured administrative framework root in indian ethos . Shivaji ’s administrative system be highly efficient , and he emphasize the welfare of his people , set up system to reduce corruption and create a fair tax structure ; his Ashta Pradhan ( Council of Eight Ministers ) include department for finance , internal affair , foreign policy , and military to ensure smooth governance . Shivaji show a progressive approach towards governance , promote religious tolerance and respect the diversity within his empire , even appoint Muslims to key position in his administration and ban the harassment of woman and looting of religious site . his respect for woman and his advocacy for justice inspire trust and loyalty among his people , make he an ideal ruler for his time . Shivaji Maharaj ’s guerrilla tactic , know as " Ganimi Kava , " become legendary and enable he to outmaneuver much large and well - equip army repeatedly , allow he to expand his empire while minimize loss . as his fame grow , the Maratha Empire begin to influence region far beyond Maharashtra , with Maratha force eventually become a significant power across India . Shivaji pass away on April 3 , 1680 , at Raigad Fort , leave behind a powerful legacy and a well - organize state that continue to expand after his death . his life and ideal — valor , respect for all faith , and self - rule — continue to inspire million , and his legacy endure in the form of the Maratha Empire ’s contribution to India ’s history and culture .
#
# Lemmatized Text using NLTK (verbs only): Chhatrapati Shivaji Maharaj be bear on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influence Shivaji with her teachings on dharma, bravery, and justice. From an early age, Shivaji exhibit remarkable leadership qualities, form a group of loyal followers and hone his military skills in the rugged terrain of the Sahyadri mountains. He grow up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates be vie for control, often oppress the local population, which deeply disturb him and fuel his desire to establish Swarajya, or self-rule for the Marathas. By the age of 16, Shivaji have capture his first fort, Torna, use guerrilla warfare tactics that would later become a hallmark of his military strategy. As his conquests grew, he form alliances with local leaders, secure key forts like Raigad, Kondana, and Purandar, establish a solid territorial base in western India. In 1659, he face and defeat Afzal Khan, a prominent general of the Bijapur Sultanate, solidify his reputation as a brave and tactical leader; this victory be crucial in establish his control over much of the Deccan. Shivaji’s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolster his legend. He realize that a powerful navy be crucial to safeguard his territories from foreign invasions, lead him to develop one of the earliest organize naval forces in India, allow him to secure coastal areas against Portuguese, British, and Siddis forces. In 1674, he formally crown himself as Chhatrapati at Raigad Fort, declare his independence and establish the Maratha Empire, thus become the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework root in Indian ethos. Shivaji’s administrative system be highly efficient, and he emphasize the welfare of his people, set up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) include departments for finance, internal affairs, foreign policy, and military to ensure smooth governance. Shivaji show a progressive approach towards governance, promote religious tolerance and respect the diversity within his empire, even appoint Muslims to key positions in his administration and ban the harassment of women and looting of religious sites. His respect for women and his advocacy for justice inspire trust and loyalty among his people, make him an ideal ruler for his time. Shivaji Maharaj’s guerrilla tactics, know as “Ganimi Kava,” become legendary and enable him to outmaneuver much larger and better-equipped armies repeatedly, allow him to expand his empire while minimize losses. As his fame grew, the Maratha Empire begin to influence regions far beyond Maharashtra, with Maratha forces eventually become a significant power across India. Shivaji pass away on April 3, 1680, at Raigad Fort, leave behind a powerful legacy and a well-organized state that continue to expand after his death. His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endure in the form of the Maratha Empire’s contributions to India’s history and culture.

# %%
from textblob import TextBlob
# Perform sentiment analysis on the entire text
overall_sentiment = TextBlob(text).sentiment

sentences = TextBlob(text).sentences

# Analyze the sentiment of each sentence
sentence_sentiments = [(str(sentence), sentence.sentiment) for sentence in sentences]

print("Overall Sentiment (Polarity, Subjectivity):", overall_sentiment)
print("\nSentiment Analysis of Each Sentence:")
for sentence, sentiment in sentence_sentiments:
    print(f"Sentence: {sentence} -> Sentiment (Polarity: {sentiment.polarity}, Subjectivity: {sentiment.subjectivity})")
# Out:
# Overall Sentiment (Polarity, Subjectivity): Sentiment(polarity=0.15890070921985816, subjectivity=0.5364893617021277)
#
# Sentiment Analysis of Each Sentence:
# Sentence: Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice. -> Sentiment (Polarity: 0.02500000000000001, Subjectivity: 0.45)
# Sentence: From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains. -> Sentiment (Polarity: 0.2708333333333333, Subjectivity: 0.49583333333333335)
# Sentence: He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often oppressing the local population, which deeply disturbed him and fueled his desire to establish Swarajya, or self-rule for the Marathas. -> Sentiment (Polarity: 0.0, Subjectivity: 0.2)
# Sentence: By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy. -> Sentiment (Polarity: 0.049999999999999996, Subjectivity: 0.14444444444444446)
# Sentence: As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India. -> Sentiment (Polarity: -0.16, Subjectivity: 0.42000000000000004)
# Sentence: In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan. -> Sentiment (Polarity: 0.31, Subjectivity: 0.74)
# Sentence: Shivaji’s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolstered his legend. -> Sentiment (Polarity: 0.0, Subjectivity: 0.5)
# Sentence: He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces. -> Sentiment (Polarity: 0.11499999999999999, Subjectivity: 0.545)
# Sentence: In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos. -> Sentiment (Polarity: 0.3666666666666667, Subjectivity: 0.6277777777777778)
# Sentence: Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance. -> Sentiment (Polarity: 0.17250000000000001, Subjectivity: 0.36083333333333334)
# Sentence: Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites. -> Sentiment (Polarity: 0.0, Subjectivity: 0.5)
# Sentence: His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time. -> Sentiment (Polarity: 0.9, Subjectivity: 1.0)
# Sentence: Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses. -> Sentiment (Polarity: 0.5, Subjectivity: 0.75)
# Sentence: As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India. -> Sentiment (Polarity: 0.30833333333333335, Subjectivity: 0.9083333333333333)
# Sentence: Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death. -> Sentiment (Polarity: -0.05000000000000002, Subjectivity: 0.85)
# Sentence: His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endures in the form of the Maratha Empire’s contributions to India’s history and culture. -> Sentiment (Polarity: 0.0, Subjectivity: 0.0)

# %%
import nltk
from nltk import bigrams
from textblob import TextBlob
nltk.download('punkt')

tokens = nltk.word_tokenize(text)

# Generate bigrams using NLTK
bigram_list = list(bigrams(tokens))

# Generate trigrams using TextBlob
blob = TextBlob(text)
trigram_list = blob.ngrams(n=3)

print("Bigrams:")
for bigram in bigram_list:
    print(bigram)

print("\nTrigrams:")
for trigram in trigram_list:
    print(trigram)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Bigrams:
# ('Chhatrapati', 'Shivaji')
# ('Shivaji', 'Maharaj')
# ('Maharaj', 'was')
# ('was', 'born')
# ('born', 'on')
# ('on', 'February')
# ('February', '19')
# ('19', ',')
# (',', '1630')
# ('1630', ',')
# (',', 'at')
# ('at', 'Shivneri')
# ('Shivneri', 'Fort')
# ('Fort', 'in')
# ('in', 'Maharashtra')
# ('Maharashtra', ',')
# (',', 'to')
# ('to', 'Shahaji')
# ('Shahaji', 'Bhonsle')
# ('Bhonsle', ',')
# (',', 'a')
# ('a', 'Maratha')
# ('Maratha', 'general')
# ('general', ',')
# (',', 'and')
# ('and', 'Jijabai')
# ('Jijabai', ',')
# (',', 'who')
# ('who', 'deeply')
# ('deeply', 'influenced')
# ('influenced', 'Shivaji')
# ('Shivaji', 'with')
# ('with', 'her')
# ('her', 'teachings')
# ('teachings', 'on')
# ('on', 'dharma')
# ('dharma', ',')
# (',', 'bravery')
# ('bravery', ',')
# (',', 'and')
# ('and', 'justice')
# ('justice', '.')
# ('.', 'From')
# ('From', 'an')
# ('an', 'early')
# ('early', 'age')
# ('age', ',')
# (',', 'Shivaji')
# ('Shivaji', 'exhibited')
# ('exhibited', 'remarkable')
# ('remarkable', 'leadership')
# ('leadership', 'qualities')
# ('qualities', ',')
# (',', 'forming')
# ('forming', 'a')
# ('a', 'group')
# ('group', 'of')
# ('of', 'loyal')
# ('loyal', 'followers')
# ('followers', 'and')
# ('and', 'honing')
# ('honing', 'his')
# ('his', 'military')
# ('military', 'skills')
# ('skills', 'in')
# ('in', 'the')
# ('the', 'rugged')
# ('rugged', 'terrain')
# ('terrain', 'of')
# ('of', 'the')
# ('the', 'Sahyadri')
# ('Sahyadri', 'mountains')
# ('mountains', '.')
# ('.', 'He')
# ('He', 'grew')
# ('grew', 'up')
# ('up', 'during')
# ('during', 'a')
# ('a', 'time')
# ('time', 'when')
# ('when', 'the')
# ('the', 'Mughal')
# ('Mughal', 'Empire')
# ('Empire', 'under')
# ('under', 'Emperor')
# ('Emperor', 'Aurangzeb')
# ('Aurangzeb', 'and')
# ('and', 'the')
# ('the', 'Deccan')
# ('Deccan', 'Sultanates')
# ('Sultanates', 'were')
# ('were', 'vying')
# ('vying', 'for')
# ('for', 'control')
# ('control', ',')
# (',', 'often')
# ('often', 'oppressing')
# ('oppressing', 'the')
# ('the', 'local')
# ('local', 'population')
# ('population', ',')
# (',', 'which')
# ('which', 'deeply')
# ('deeply', 'disturbed')
# ('disturbed', 'him')
# ('him', 'and')
# ('and', 'fueled')
# ('fueled', 'his')
# ('his', 'desire')
# ('desire', 'to')
# ('to', 'establish')
# ('establish', 'Swarajya')
# ('Swarajya', ',')
# (',', 'or')
# ('or', 'self-rule')
# ('self-rule', 'for')
# ('for', 'the')
# ('the', 'Marathas')
# ('Marathas', '.')
# ('.', 'By')
# ('By', 'the')
# ('the', 'age')
# ('age', 'of')
# ('of', '16')
# ('16', ',')
# (',', 'Shivaji')
# ('Shivaji', 'had')
# ('had', 'captured')
# ('captured', 'his')
# ('his', 'first')
# ('first', 'fort')
# ('fort', ',')
# (',', 'Torna')
# ('Torna', ',')
# (',', 'using')
# ('using', 'guerrilla')
# ('guerrilla', 'warfare')
# ('warfare', 'tactics')
# ('tactics', 'that')
# ('that', 'would')
# ('would', 'later')
# ('later', 'become')
# ('become', 'a')
# ('a', 'hallmark')
# ('hallmark', 'of')
# ('of', 'his')
# ('his', 'military')
# ('military', 'strategy')
# ('strategy', '.')
# ('.', 'As')
# ('As', 'his')
# ('his', 'conquests')
# ('conquests', 'grew')
# ('grew', ',')
# (',', 'he')
# ('he', 'formed')
# ('formed', 'alliances')
# ('alliances', 'with')
# ('with', 'local')
# ('local', 'leaders')
# ('leaders', ',')
# (',', 'securing')
# ('securing', 'key')
# ('key', 'forts')
# ('forts', 'like')
# ('like', 'Raigad')
# ('Raigad', ',')
# (',', 'Kondana')
# ('Kondana', ',')
# (',', 'and')
# ('and', 'Purandar')
# ('Purandar', ',')
# (',', 'establishing')
# ('establishing', 'a')
# ('a', 'solid')
# ('solid', 'territorial')
# ('territorial', 'base')
# ('base', 'in')
# ('in', 'western')
# ('western', 'India')
# ('India', '.')
# ('.', 'In')
# ('In', '1659')
# ('1659', ',')
# (',', 'he')
# ('he', 'faced')
# ('faced', 'and')
# ('and', 'defeated')
# ('defeated', 'Afzal')
# ('Afzal', 'Khan')
# ('Khan', ',')
# (',', 'a')
# ('a', 'prominent')
# ('prominent', 'general')
# ('general', 'of')
# ('of', 'the')
# ('the', 'Bijapur')
# ('Bijapur', 'Sultanate')
# ('Sultanate', ',')
# (',', 'solidifying')
# ('solidifying', 'his')
# ('his', 'reputation')
# ('reputation', 'as')
# ('as', 'a')
# ('a', 'brave')
# ('brave', 'and')
# ('and', 'tactical')
# ('tactical', 'leader')
# ('leader', ';')
# (';', 'this')
# ('this', 'victory')
# ('victory', 'was')
# ('was', 'crucial')
# ('crucial', 'in')
# ('in', 'establishing')
# ('establishing', 'his')
# ('his', 'control')
# ('control', 'over')
# ('over', 'much')
# ('much', 'of')
# ('of', 'the')
# ('the', 'Deccan')
# ('Deccan', '.')
# ('.', 'Shivaji')
# ('Shivaji', '’')
# ('’', 's')
# ('s', 'raids')
# ('raids', 'on')
# ('on', 'Mughal')
# ('Mughal', 'territories')
# ('territories', 'and')
# ('and', 'his')
# ('his', 'escape')
# ('escape', 'from')
# ('from', 'the')
# ('the', 'clutches')
# ('clutches', 'of')
# ('of', 'Aurangzeb')
# ('Aurangzeb', 'in')
# ('in', 'Agra')
# ('Agra', 'in')
# ('in', '1666')
# ('1666', 'further')
# ('further', 'bolstered')
# ('bolstered', 'his')
# ('his', 'legend')
# ('legend', '.')
# ('.', 'He')
# ('He', 'realized')
# ('realized', 'that')
# ('that', 'a')
# ('a', 'powerful')
# ('powerful', 'navy')
# ('navy', 'was')
# ('was', 'crucial')
# ('crucial', 'to')
# ('to', 'safeguard')
# ('safeguard', 'his')
# ('his', 'territories')
# ('territories', 'from')
# ('from', 'foreign')
# ('foreign', 'invasions')
# ('invasions', ',')
# (',', 'leading')
# ('leading', 'him')
# ('him', 'to')
# ('to', 'develop')
# ('develop', 'one')
# ('one', 'of')
# ('of', 'the')
# ('the', 'earliest')
# ('earliest', 'organized')
# ('organized', 'naval')
# ('naval', 'forces')
# ('forces', 'in')
# ('in', 'India')
# ('India', ',')
# (',', 'allowing')
# ('allowing', 'him')
# ('him', 'to')
# ('to', 'secure')
# ('secure', 'coastal')
# ('coastal', 'areas')
# ('areas', 'against')
# ('against', 'Portuguese')
# ('Portuguese', ',')
# (',', 'British')
# ('British', ',')
# (',', 'and')
# ('and', 'Siddis')
# ('Siddis', 'forces')
# ('forces', '.')
# ('.', 'In')
# ('In', '1674')
# ('1674', ',')
# (',', 'he')
# ('he', 'formally')
# ('formally', 'crowned')
# ('crowned', 'himself')
# ('himself', 'as')
# ('as', 'Chhatrapati')
# ('Chhatrapati', 'at')
# ('at', 'Raigad')
# ('Raigad', 'Fort')
# ('Fort', ',')
# (',', 'declaring')
# ('declaring', 'his')
# ('his', 'independence')
# ('independence', 'and')
# ('and', 'establishing')
# ('establishing', 'the')
# ('the', 'Maratha')
# ('Maratha', 'Empire')
# ('Empire', ',')
# (',', 'thus')
# ('thus', 'becoming')
# ('becoming', 'the')
# ('the', 'first')
# ('first', 'king')
# ('king', 'to')
# ('to', 'establish')
# ('establish', 'Hindavi')
# ('Hindavi', 'Swarajya')
# ('Swarajya', ',')
# (',', 'an')
# ('an', 'autonomous')
# ('autonomous', 'kingdom')
# ('kingdom', 'with')
# ('with', 'a')
# ('a', 'structured')
# ('structured', 'administrative')
# ('administrative', 'framework')
# ('framework', 'rooted')
# ('rooted', 'in')
# ('in', 'Indian')
# ('Indian', 'ethos')
# ('ethos', '.')
# ('.', 'Shivaji')
# ('Shivaji', '’')
# ('’', 's')
# ('s', 'administrative')
# ('administrative', 'system')
# ('system', 'was')
# ('was', 'highly')
# ('highly', 'efficient')
# ('efficient', ',')
# (',', 'and')
# ('and', 'he')
# ('he', 'emphasized')
# ('emphasized', 'the')
# ('the', 'welfare')
# ('welfare', 'of')
# ('of', 'his')
# ('his', 'people')
# ('people', ',')
# (',', 'setting')
# ('setting', 'up')
# ('up', 'systems')
# ('systems', 'to')
# ('to', 'reduce')
# ('reduce', 'corruption')
# ('corruption', 'and')
# ('and', 'create')
# ('create', 'a')
# ('a', 'fair')
# ('fair', 'tax')
# ('tax', 'structure')
# ('structure', ';')
# (';', 'his')
# ('his', 'Ashta')
# ('Ashta', 'Pradhan')
# ('Pradhan', '(')
# ('(', 'Council')
# ('Council', 'of')
# ('of', 'Eight')
# ('Eight', 'Ministers')
# ('Ministers', ')')
# (')', 'included')
# ('included', 'departments')
# ('departments', 'for')
# ('for', 'finance')
# ('finance', ',')
# (',', 'internal')
# ('internal', 'affairs')
# ('affairs', ',')
# (',', 'foreign')
# ('foreign', 'policy')
# ('policy', ',')
# (',', 'and')
# ('and', 'military')
# ('military', 'to')
# ('to', 'ensure')
# ('ensure', 'smooth')
# ('smooth', 'governance')
# ('governance', '.')
# ('.', 'Shivaji')
# ('Shivaji', 'showed')
# ('showed', 'a')
# ('a', 'progressive')
# ('progressive', 'approach')
# ('approach', 'towards')
# ('towards', 'governance')
# ('governance', ',')
# (',', 'promoting')
# ('promoting', 'religious')
# ('religious', 'tolerance')
# ('tolerance', 'and')
# ('and', 'respecting')
# ('respecting', 'the')
# ('the', 'diversity')
# ('diversity', 'within')
# ('within', 'his')
# ('his', 'empire')
# ('empire', ',')
# (',', 'even')
# ('even', 'appointing')
# ('appointing', 'Muslims')
# ('Muslims', 'to')
# ('to', 'key')
# ('key', 'positions')
# ('positions', 'in')
# ('in', 'his')
# ('his', 'administration')
# ('administration', 'and')
# ('and', 'banning')
# ('banning', 'the')
# ('the', 'harassment')
# ('harassment', 'of')
# ('of', 'women')
# ('women', 'and')
# ('and', 'looting')
# ('looting', 'of')
# ('of', 'religious')
# ('religious', 'sites')
# ('sites', '.')
# ('.', 'His')
# ('His', 'respect')
# ('respect', 'for')
# ('for', 'women')
# ('women', 'and')
# ('and', 'his')
# ('his', 'advocacy')
# ('advocacy', 'for')
# ('for', 'justice')
# ('justice', 'inspired')
# ('inspired', 'trust')
# ('trust', 'and')
# ('and', 'loyalty')
# ('loyalty', 'among')
# ('among', 'his')
# ('his', 'people')
# ('people', ',')
# (',', 'making')
# ('making', 'him')
# ('him', 'an')
# ('an', 'ideal')
# ('ideal', 'ruler')
# ('ruler', 'for')
# ('for', 'his')
# ('his', 'time')
# ('time', '.')
# ('.', 'Shivaji')
# ('Shivaji', 'Maharaj')
# ('Maharaj', '’')
# ('’', 's')
# ('s', 'guerrilla')
# ('guerrilla', 'tactics')
# ('tactics', ',')
# (',', 'known')
# ('known', 'as')
# ('as', '“')
# ('“', 'Ganimi')
# ('Ganimi', 'Kava')
# ('Kava', ',')
# (',', '”')
# ('”', 'became')
# ('became', 'legendary')
# ('legendary', 'and')
# ('and', 'enabled')
# ('enabled', 'him')
# ('him', 'to')
# ('to', 'outmaneuver')
# ('outmaneuver', 'much')
# ('much', 'larger')
# ('larger', 'and')
# ('and', 'better-equipped')
# ('better-equipped', 'armies')
# ('armies', 'repeatedly')
# ('repeatedly', ',')
# (',', 'allowing')
# ('allowing', 'him')
# ('him', 'to')
# ('to', 'expand')
# ('expand', 'his')
# ('his', 'empire')
# ('empire', 'while')
# ('while', 'minimizing')
# ('minimizing', 'losses')
# ('losses', '.')
# ('.', 'As')
# ('As', 'his')
# ('his', 'fame')
# ('fame', 'grew')
# ('grew', ',')
# (',', 'the')
# ('the', 'Maratha')
# ('Maratha', 'Empire')
# ('Empire', 'began')
# ('began', 'to')
# ('to', 'influence')
# ('influence', 'regions')
# ('regions', 'far')
# ('far', 'beyond')
# ('beyond', 'Maharashtra')
# ('Maharashtra', ',')
# (',', 'with')
# ('with', 'Maratha')
# ('Maratha', 'forces')
# ('forces', 'eventually')
# ('eventually', 'becoming')
# ('becoming', 'a')
# ('a', 'significant')
# ('significant', 'power')
# ('power', 'across')
# ('across', 'India')
# ('India', '.')
# ('.', 'Shivaji')
# ('Shivaji', 'passed')
# ('passed', 'away')
# ('away', 'on')
# ('on', 'April')
# ('April', '3')
# ('3', ',')
# (',', '1680')
# ('1680', ',')
# (',', 'at')
# ('at', 'Raigad')
# ('Raigad', 'Fort')
# ('Fort', ',')
# (',', 'leaving')
# ('leaving', 'behind')
# ('behind', 'a')
# ('a', 'powerful')
# ('powerful', 'legacy')
# ('legacy', 'and')
# ('and', 'a')
# ('a', 'well-organized')
# ('well-organized', 'state')
# ('state', 'that')
# ('that', 'continued')
# ('continued', 'to')
# ('to', 'expand')
# ('expand', 'after')
# ('after', 'his')
# ('his', 'death')
# ('death', '.')
# ('.', 'His')
# ('His', 'life')
# ('life', 'and')
# ('and', 'ideals—valor')
# ('ideals—valor', ',')
# (',', 'respect')
# ('respect', 'for')
# ('for', 'all')
# ('all', 'faiths')
# ('faiths', ',')
# (',', 'and')
# ('and', 'self-rule—continue')
# ('self-rule—continue', 'to')
# ('to', 'inspire')
# ('inspire', 'millions')
# ('millions', ',')
# (',', 'and')
# ('and', 'his')
# ('his', 'legacy')
# ('legacy', 'endures')
# ('endures', 'in')
# ('in', 'the')
# ('the', 'form')
# ('form', 'of')
# ('of', 'the')
# ('the', 'Maratha')
# ('Maratha', 'Empire')
# ('Empire', '’')
# ('’', 's')
# ('s', 'contributions')
# ('contributions', 'to')
# ('to', 'India')
# ('India', '’')
# ('’', 's')
# ('s', 'history')
# ('history', 'and')
# ('and', 'culture')
# ('culture', '.')
#
# Trigrams:
# ['Chhatrapati', 'Shivaji', 'Maharaj']
# ['Shivaji', 'Maharaj', 'was']
# ['Maharaj', 'was', 'born']
# ['was', 'born', 'on']
# ['born', 'on', 'February']
# ['on', 'February', '19']
# ['February', '19', '1630']
# ['19', '1630', 'at']
# ['1630', 'at', 'Shivneri']
# ['at', 'Shivneri', 'Fort']
# ['Shivneri', 'Fort', 'in']
# ['Fort', 'in', 'Maharashtra']
# ['in', 'Maharashtra', 'to']
# ['Maharashtra', 'to', 'Shahaji']
# ['to', 'Shahaji', 'Bhonsle']
# ['Shahaji', 'Bhonsle', 'a']
# ['Bhonsle', 'a', 'Maratha']
# ['a', 'Maratha', 'general']
# ['Maratha', 'general', 'and']
# ['general', 'and', 'Jijabai']
# ['and', 'Jijabai', 'who']
# ['Jijabai', 'who', 'deeply']
# ['who', 'deeply', 'influenced']
# ['deeply', 'influenced', 'Shivaji']
# ['influenced', 'Shivaji', 'with']
# ['Shivaji', 'with', 'her']
# ['with', 'her', 'teachings']
# ['her', 'teachings', 'on']
# ['teachings', 'on', 'dharma']
# ['on', 'dharma', 'bravery']
# ['dharma', 'bravery', 'and']
# ['bravery', 'and', 'justice']
# ['and', 'justice', 'From']
# ['justice', 'From', 'an']
# ['From', 'an', 'early']
# ['an', 'early', 'age']
# ['early', 'age', 'Shivaji']
# ['age', 'Shivaji', 'exhibited']
# ['Shivaji', 'exhibited', 'remarkable']
# ['exhibited', 'remarkable', 'leadership']
# ['remarkable', 'leadership', 'qualities']
# ['leadership', 'qualities', 'forming']
# ['qualities', 'forming', 'a']
# ['forming', 'a', 'group']
# ['a', 'group', 'of']
# ['group', 'of', 'loyal']
# ['of', 'loyal', 'followers']
# ['loyal', 'followers', 'and']
# ['followers', 'and', 'honing']
# ['and', 'honing', 'his']
# ['honing', 'his', 'military']
# ['his', 'military', 'skills']
# ['military', 'skills', 'in']
# ['skills', 'in', 'the']
# ['in', 'the', 'rugged']
# ['the', 'rugged', 'terrain']
# ['rugged', 'terrain', 'of']
# ['terrain', 'of', 'the']
# ['of', 'the', 'Sahyadri']
# ['the', 'Sahyadri', 'mountains']
# ['Sahyadri', 'mountains', 'He']
# ['mountains', 'He', 'grew']
# ['He', 'grew', 'up']
# ['grew', 'up', 'during']
# ['up', 'during', 'a']
# ['during', 'a', 'time']
# ['a', 'time', 'when']
# ['time', 'when', 'the']
# ['when', 'the', 'Mughal']
# ['the', 'Mughal', 'Empire']
# ['Mughal', 'Empire', 'under']
# ['Empire', 'under', 'Emperor']
# ['under', 'Emperor', 'Aurangzeb']
# ['Emperor', 'Aurangzeb', 'and']
# ['Aurangzeb', 'and', 'the']
# ['and', 'the', 'Deccan']
# ['the', 'Deccan', 'Sultanates']
# ['Deccan', 'Sultanates', 'were']
# ['Sultanates', 'were', 'vying']
# ['were', 'vying', 'for']
# ['vying', 'for', 'control']
# ['for', 'control', 'often']
# ['control', 'often', 'oppressing']
# ['often', 'oppressing', 'the']
# ['oppressing', 'the', 'local']
# ['the', 'local', 'population']
# ['local', 'population', 'which']
# ['population', 'which', 'deeply']
# ['which', 'deeply', 'disturbed']
# ['deeply', 'disturbed', 'him']
# ['disturbed', 'him', 'and']
# ['him', 'and', 'fueled']
# ['and', 'fueled', 'his']
# ['fueled', 'his', 'desire']
# ['his', 'desire', 'to']
# ['desire', 'to', 'establish']
# ['to', 'establish', 'Swarajya']
# ['establish', 'Swarajya', 'or']
# ['Swarajya', 'or', 'self-rule']
# ['or', 'self-rule', 'for']
# ['self-rule', 'for', 'the']
# ['for', 'the', 'Marathas']
# ['the', 'Marathas', 'By']
# ['Marathas', 'By', 'the']
# ['By', 'the', 'age']
# ['the', 'age', 'of']
# ['age', 'of', '16']
# ['of', '16', 'Shivaji']
# ['16', 'Shivaji', 'had']
# ['Shivaji', 'had', 'captured']
# ['had', 'captured', 'his']
# ['captured', 'his', 'first']
# ['his', 'first', 'fort']
# ['first', 'fort', 'Torna']
# ['fort', 'Torna', 'using']
# ['Torna', 'using', 'guerrilla']
# ['using', 'guerrilla', 'warfare']
# ['guerrilla', 'warfare', 'tactics']
# ['warfare', 'tactics', 'that']
# ['tactics', 'that', 'would']
# ['that', 'would', 'later']
# ['would', 'later', 'become']
# ['later', 'become', 'a']
# ['become', 'a', 'hallmark']
# ['a', 'hallmark', 'of']
# ['hallmark', 'of', 'his']
# ['of', 'his', 'military']
# ['his', 'military', 'strategy']
# ['military', 'strategy', 'As']
# ['strategy', 'As', 'his']
# ['As', 'his', 'conquests']
# ['his', 'conquests', 'grew']
# ['conquests', 'grew', 'he']
# ['grew', 'he', 'formed']
# ['he', 'formed', 'alliances']
# ['formed', 'alliances', 'with']
# ['alliances', 'with', 'local']
# ['with', 'local', 'leaders']
# ['local', 'leaders', 'securing']
# ['leaders', 'securing', 'key']
# ['securing', 'key', 'forts']
# ['key', 'forts', 'like']
# ['forts', 'like', 'Raigad']
# ['like', 'Raigad', 'Kondana']
# ['Raigad', 'Kondana', 'and']
# ['Kondana', 'and', 'Purandar']
# ['and', 'Purandar', 'establishing']
# ['Purandar', 'establishing', 'a']
# ['establishing', 'a', 'solid']
# ['a', 'solid', 'territorial']
# ['solid', 'territorial', 'base']
# ['territorial', 'base', 'in']
# ['base', 'in', 'western']
# ['in', 'western', 'India']
# ['western', 'India', 'In']
# ['India', 'In', '1659']
# ['In', '1659', 'he']
# ['1659', 'he', 'faced']
# ['he', 'faced', 'and']
# ['faced', 'and', 'defeated']
# ['and', 'defeated', 'Afzal']
# ['defeated', 'Afzal', 'Khan']
# ['Afzal', 'Khan', 'a']
# ['Khan', 'a', 'prominent']
# ['a', 'prominent', 'general']
# ['prominent', 'general', 'of']
# ['general', 'of', 'the']
# ['of', 'the', 'Bijapur']
# ['the', 'Bijapur', 'Sultanate']
# ['Bijapur', 'Sultanate', 'solidifying']
# ['Sultanate', 'solidifying', 'his']
# ['solidifying', 'his', 'reputation']
# ['his', 'reputation', 'as']
# ['reputation', 'as', 'a']
# ['as', 'a', 'brave']
# ['a', 'brave', 'and']
# ['brave', 'and', 'tactical']
# ['and', 'tactical', 'leader']
# ['tactical', 'leader', 'this']
# ['leader', 'this', 'victory']
# ['this', 'victory', 'was']
# ['victory', 'was', 'crucial']
# ['was', 'crucial', 'in']
# ['crucial', 'in', 'establishing']
# ['in', 'establishing', 'his']
# ['establishing', 'his', 'control']
# ['his', 'control', 'over']
# ['control', 'over', 'much']
# ['over', 'much', 'of']
# ['much', 'of', 'the']
# ['of', 'the', 'Deccan']
# ['the', 'Deccan', 'Shivaji']
# ['Deccan', 'Shivaji', '’']
# ['Shivaji', '’', 's']
# ['’', 's', 'raids']
# ['s', 'raids', 'on']
# ['raids', 'on', 'Mughal']
# ['on', 'Mughal', 'territories']
# ['Mughal', 'territories', 'and']
# ['territories', 'and', 'his']
# ['and', 'his', 'escape']
# ['his', 'escape', 'from']
# ['escape', 'from', 'the']
# ['from', 'the', 'clutches']
# ['the', 'clutches', 'of']
# ['clutches', 'of', 'Aurangzeb']
# ['of', 'Aurangzeb', 'in']
# ['Aurangzeb', 'in', 'Agra']
# ['in', 'Agra', 'in']
# ['Agra', 'in', '1666']
# ['in', '1666', 'further']
# ['1666', 'further', 'bolstered']
# ['further', 'bolstered', 'his']
# ['bolstered', 'his', 'legend']
# ['his', 'legend', 'He']
# ['legend', 'He', 'realized']
# ['He', 'realized', 'that']
# ['realized', 'that', 'a']
# ['that', 'a', 'powerful']
# ['a', 'powerful', 'navy']
# ['powerful', 'navy', 'was']
# ['navy', 'was', 'crucial']
# ['was', 'crucial', 'to']
# ['crucial', 'to', 'safeguard']
# ['to', 'safeguard', 'his']
# ['safeguard', 'his', 'territories']
# ['his', 'territories', 'from']
# ['territories', 'from', 'foreign']
# ['from', 'foreign', 'invasions']
# ['foreign', 'invasions', 'leading']
# ['invasions', 'leading', 'him']
# ['leading', 'him', 'to']
# ['him', 'to', 'develop']
# ['to', 'develop', 'one']
# ['develop', 'one', 'of']
# ['one', 'of', 'the']
# ['of', 'the', 'earliest']
# ['the', 'earliest', 'organized']
# ['earliest', 'organized', 'naval']
# ['organized', 'naval', 'forces']
# ['naval', 'forces', 'in']
# ['forces', 'in', 'India']
# ['in', 'India', 'allowing']
# ['India', 'allowing', 'him']
# ['allowing', 'him', 'to']
# ['him', 'to', 'secure']
# ['to', 'secure', 'coastal']
# ['secure', 'coastal', 'areas']
# ['coastal', 'areas', 'against']
# ['areas', 'against', 'Portuguese']
# ['against', 'Portuguese', 'British']
# ['Portuguese', 'British', 'and']
# ['British', 'and', 'Siddis']
# ['and', 'Siddis', 'forces']
# ['Siddis', 'forces', 'In']
# ['forces', 'In', '1674']
# ['In', '1674', 'he']
# ['1674', 'he', 'formally']
# ['he', 'formally', 'crowned']
# ['formally', 'crowned', 'himself']
# ['crowned', 'himself', 'as']
# ['himself', 'as', 'Chhatrapati']
# ['as', 'Chhatrapati', 'at']
# ['Chhatrapati', 'at', 'Raigad']
# ['at', 'Raigad', 'Fort']
# ['Raigad', 'Fort', 'declaring']
# ['Fort', 'declaring', 'his']
# ['declaring', 'his', 'independence']
# ['his', 'independence', 'and']
# ['independence', 'and', 'establishing']
# ['and', 'establishing', 'the']
# ['establishing', 'the', 'Maratha']
# ['the', 'Maratha', 'Empire']
# ['Maratha', 'Empire', 'thus']
# ['Empire', 'thus', 'becoming']
# ['thus', 'becoming', 'the']
# ['becoming', 'the', 'first']
# ['the', 'first', 'king']
# ['first', 'king', 'to']
# ['king', 'to', 'establish']
# ['to', 'establish', 'Hindavi']
# ['establish', 'Hindavi', 'Swarajya']
# ['Hindavi', 'Swarajya', 'an']
# ['Swarajya', 'an', 'autonomous']
# ['an', 'autonomous', 'kingdom']
# ['autonomous', 'kingdom', 'with']
# ['kingdom', 'with', 'a']
# ['with', 'a', 'structured']
# ['a', 'structured', 'administrative']
# ['structured', 'administrative', 'framework']
# ['administrative', 'framework', 'rooted']
# ['framework', 'rooted', 'in']
# ['rooted', 'in', 'Indian']
# ['in', 'Indian', 'ethos']
# ['Indian', 'ethos', 'Shivaji']
# ['ethos', 'Shivaji', '’']
# ['Shivaji', '’', 's']
# ['’', 's', 'administrative']
# ['s', 'administrative', 'system']
# ['administrative', 'system', 'was']
# ['system', 'was', 'highly']
# ['was', 'highly', 'efficient']
# ['highly', 'efficient', 'and']
# ['efficient', 'and', 'he']
# ['and', 'he', 'emphasized']
# ['he', 'emphasized', 'the']
# ['emphasized', 'the', 'welfare']
# ['the', 'welfare', 'of']
# ['welfare', 'of', 'his']
# ['of', 'his', 'people']
# ['his', 'people', 'setting']
# ['people', 'setting', 'up']
# ['setting', 'up', 'systems']
# ['up', 'systems', 'to']
# ['systems', 'to', 'reduce']
# ['to', 'reduce', 'corruption']
# ['reduce', 'corruption', 'and']
# ['corruption', 'and', 'create']
# ['and', 'create', 'a']
# ['create', 'a', 'fair']
# ['a', 'fair', 'tax']
# ['fair', 'tax', 'structure']
# ['tax', 'structure', 'his']
# ['structure', 'his', 'Ashta']
# ['his', 'Ashta', 'Pradhan']
# ['Ashta', 'Pradhan', 'Council']
# ['Pradhan', 'Council', 'of']
# ['Council', 'of', 'Eight']
# ['of', 'Eight', 'Ministers']
# ['Eight', 'Ministers', 'included']
# ['Ministers', 'included', 'departments']
# ['included', 'departments', 'for']
# ['departments', 'for', 'finance']
# ['for', 'finance', 'internal']
# ['finance', 'internal', 'affairs']
# ['internal', 'affairs', 'foreign']
# ['affairs', 'foreign', 'policy']
# ['foreign', 'policy', 'and']
# ['policy', 'and', 'military']
# ['and', 'military', 'to']
# ['military', 'to', 'ensure']
# ['to', 'ensure', 'smooth']
# ['ensure', 'smooth', 'governance']
# ['smooth', 'governance', 'Shivaji']
# ['governance', 'Shivaji', 'showed']
# ['Shivaji', 'showed', 'a']
# ['showed', 'a', 'progressive']
# ['a', 'progressive', 'approach']
# ['progressive', 'approach', 'towards']
# ['approach', 'towards', 'governance']
# ['towards', 'governance', 'promoting']
# ['governance', 'promoting', 'religious']
# ['promoting', 'religious', 'tolerance']
# ['religious', 'tolerance', 'and']
# ['tolerance', 'and', 'respecting']
# ['and', 'respecting', 'the']
# ['respecting', 'the', 'diversity']
# ['the', 'diversity', 'within']
# ['diversity', 'within', 'his']
# ['within', 'his', 'empire']
# ['his', 'empire', 'even']
# ['empire', 'even', 'appointing']
# ['even', 'appointing', 'Muslims']
# ['appointing', 'Muslims', 'to']
# ['Muslims', 'to', 'key']
# ['to', 'key', 'positions']
# ['key', 'positions', 'in']
# ['positions', 'in', 'his']
# ['in', 'his', 'administration']
# ['his', 'administration', 'and']
# ['administration', 'and', 'banning']
# ['and', 'banning', 'the']
# ['banning', 'the', 'harassment']
# ['the', 'harassment', 'of']
# ['harassment', 'of', 'women']
# ['of', 'women', 'and']
# ['women', 'and', 'looting']
# ['and', 'looting', 'of']
# ['looting', 'of', 'religious']
# ['of', 'religious', 'sites']
# ['religious', 'sites', 'His']
# ['sites', 'His', 'respect']
# ['His', 'respect', 'for']
# ['respect', 'for', 'women']
# ['for', 'women', 'and']
# ['women', 'and', 'his']
# ['and', 'his', 'advocacy']
# ['his', 'advocacy', 'for']
# ['advocacy', 'for', 'justice']
# ['for', 'justice', 'inspired']
# ['justice', 'inspired', 'trust']
# ['inspired', 'trust', 'and']
# ['trust', 'and', 'loyalty']
# ['and', 'loyalty', 'among']
# ['loyalty', 'among', 'his']
# ['among', 'his', 'people']
# ['his', 'people', 'making']
# ['people', 'making', 'him']
# ['making', 'him', 'an']
# ['him', 'an', 'ideal']
# ['an', 'ideal', 'ruler']
# ['ideal', 'ruler', 'for']
# ['ruler', 'for', 'his']
# ['for', 'his', 'time']
# ['his', 'time', 'Shivaji']
# ['time', 'Shivaji', 'Maharaj']
# ['Shivaji', 'Maharaj', '’']
# ['Maharaj', '’', 's']
# ['’', 's', 'guerrilla']
# ['s', 'guerrilla', 'tactics']
# ['guerrilla', 'tactics', 'known']
# ['tactics', 'known', 'as']
# ['known', 'as', '“']
# ['as', '“', 'Ganimi']
# ['“', 'Ganimi', 'Kava']
# ['Ganimi', 'Kava', '”']
# ['Kava', '”', 'became']
# ['”', 'became', 'legendary']
# ['became', 'legendary', 'and']
# ['legendary', 'and', 'enabled']
# ['and', 'enabled', 'him']
# ['enabled', 'him', 'to']
# ['him', 'to', 'outmaneuver']
# ['to', 'outmaneuver', 'much']
# ['outmaneuver', 'much', 'larger']
# ['much', 'larger', 'and']
# ['larger', 'and', 'better-equipped']
# ['and', 'better-equipped', 'armies']
# ['better-equipped', 'armies', 'repeatedly']
# ['armies', 'repeatedly', 'allowing']
# ['repeatedly', 'allowing', 'him']
# ['allowing', 'him', 'to']
# ['him', 'to', 'expand']
# ['to', 'expand', 'his']
# ['expand', 'his', 'empire']
# ['his', 'empire', 'while']
# ['empire', 'while', 'minimizing']
# ['while', 'minimizing', 'losses']
# ['minimizing', 'losses', 'As']
# ['losses', 'As', 'his']
# ['As', 'his', 'fame']
# ['his', 'fame', 'grew']
# ['fame', 'grew', 'the']
# ['grew', 'the', 'Maratha']
# ['the', 'Maratha', 'Empire']
# ['Maratha', 'Empire', 'began']
# ['Empire', 'began', 'to']
# ['began', 'to', 'influence']
# ['to', 'influence', 'regions']
# ['influence', 'regions', 'far']
# ['regions', 'far', 'beyond']
# ['far', 'beyond', 'Maharashtra']
# ['beyond', 'Maharashtra', 'with']
# ['Maharashtra', 'with', 'Maratha']
# ['with', 'Maratha', 'forces']
# ['Maratha', 'forces', 'eventually']
# ['forces', 'eventually', 'becoming']
# ['eventually', 'becoming', 'a']
# ['becoming', 'a', 'significant']
# ['a', 'significant', 'power']
# ['significant', 'power', 'across']
# ['power', 'across', 'India']
# ['across', 'India', 'Shivaji']
# ['India', 'Shivaji', 'passed']
# ['Shivaji', 'passed', 'away']
# ['passed', 'away', 'on']
# ['away', 'on', 'April']
# ['on', 'April', '3']
# ['April', '3', '1680']
# ['3', '1680', 'at']
# ['1680', 'at', 'Raigad']
# ['at', 'Raigad', 'Fort']
# ['Raigad', 'Fort', 'leaving']
# ['Fort', 'leaving', 'behind']
# ['leaving', 'behind', 'a']
# ['behind', 'a', 'powerful']
# ['a', 'powerful', 'legacy']
# ['powerful', 'legacy', 'and']
# ['legacy', 'and', 'a']
# ['and', 'a', 'well-organized']
# ['a', 'well-organized', 'state']
# ['well-organized', 'state', 'that']
# ['state', 'that', 'continued']
# ['that', 'continued', 'to']
# ['continued', 'to', 'expand']
# ['to', 'expand', 'after']
# ['expand', 'after', 'his']
# ['after', 'his', 'death']
# ['his', 'death', 'His']
# ['death', 'His', 'life']
# ['His', 'life', 'and']
# ['life', 'and', 'ideals—valor']
# ['and', 'ideals—valor', 'respect']
# ['ideals—valor', 'respect', 'for']
# ['respect', 'for', 'all']
# ['for', 'all', 'faiths']
# ['all', 'faiths', 'and']
# ['faiths', 'and', 'self-rule—continue']
# ['and', 'self-rule—continue', 'to']
# ['self-rule—continue', 'to', 'inspire']
# ['to', 'inspire', 'millions']
# ['inspire', 'millions', 'and']
# ['millions', 'and', 'his']
# ['and', 'his', 'legacy']
# ['his', 'legacy', 'endures']
# ['legacy', 'endures', 'in']
# ['endures', 'in', 'the']
# ['in', 'the', 'form']
# ['the', 'form', 'of']
# ['form', 'of', 'the']
# ['of', 'the', 'Maratha']
# ['the', 'Maratha', 'Empire']
# ['Maratha', 'Empire', '’']
# ['Empire', '’', 's']
# ['’', 's', 'contributions']
# ['s', 'contributions', 'to']
# ['contributions', 'to', 'India']
# ['to', 'India', '’']
# ['India', '’', 's']
# ['’', 's', 'history']
# ['s', 'history', 'and']
# ['history', 'and', 'culture']

# %%
import nltk
from nltk import FreqDist

nltk.download('punkt')

nlp = spacy.load("en_core_web_sm")
tokens = word_tokenize(text)

# Compute the frequency distribution of words using NLTK
freq_dist = FreqDist(tokens)


print("Frequency Distribution:")
for word, frequency in freq_dist.most_common(10):
    print(f"{word}: {frequency}")

doc = nlp(text)

# Extract nouns and their frequencies
nouns = [token.text for token in doc if token.pos_ == "NOUN"]
noun_freq_dist = FreqDist(nouns)

# Find the 5 most common nouns
print("\nMost Common Nouns:")
for noun, frequency in noun_freq_dist.most_common(5):
    print(f"{noun}: {frequency}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Frequency Distribution:
# ,: 51
# and: 26
# his: 22
# the: 19
# .: 16
# to: 15
# a: 14
# of: 13
# in: 10
# Shivaji: 9
#
# Most Common Nouns:
# forces: 3
# general: 2
# justice: 2
# age: 2
# time: 2

# %%
import spacy
from spacy import displacy
nlp = spacy.load("en_core_web_sm")

doc = nlp(text)

print("Dependency Parse Information:")
for sent in doc.sents:
    print(f"\nSentence: {sent.text}")
    for token in sent:
        print(f"{token.text:15} -> {token.dep_:10} -> {token.head.text}")

# Visualize the dependency tree of the first sentence
if doc.sents:
    first_sentence = list(doc.sents)[0]
    print("\nVisualizing Dependency Tree for the First Sentence:")
    displacy.render(first_sentence, style="dep", jupyter=True)
# Out:
# Dependency Parse Information:
#
# Sentence: Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice.
# Chhatrapati     -> compound   -> Maharaj
# Shivaji         -> compound   -> Maharaj
# Maharaj         -> nsubjpass  -> born
# was             -> auxpass    -> born
# born            -> ROOT       -> born
# on              -> prep       -> born
# February        -> pobj       -> on
# 19              -> nummod     -> February
# ,               -> punct      -> February
# 1630            -> nummod     -> February
# ,               -> punct      -> February
# at              -> prep       -> February
# Shivneri        -> compound   -> Fort
# Fort            -> pobj       -> at
# in              -> prep       -> Fort
# Maharashtra     -> pobj       -> in
# ,               -> punct      -> February
# to              -> prep       -> born
# Shahaji         -> compound   -> Bhonsle
# Bhonsle         -> pobj       -> to
# ,               -> punct      -> Bhonsle
# a               -> det        -> general
# Maratha         -> compound   -> general
# general         -> appos      -> Bhonsle
# ,               -> punct      -> general
# and             -> cc         -> general
# Jijabai         -> conj       -> general
# ,               -> punct      -> general
# who             -> nsubj      -> influenced
# deeply          -> advmod     -> influenced
# influenced      -> relcl      -> general
# Shivaji         -> dobj       -> influenced
# with            -> prep       -> influenced
# her             -> poss       -> teachings
# teachings       -> pobj       -> with
# on              -> prep       -> teachings
# dharma          -> pobj       -> on
# ,               -> punct      -> dharma
# bravery         -> conj       -> dharma
# ,               -> punct      -> bravery
# and             -> cc         -> bravery
# justice         -> conj       -> bravery
# .               -> punct      -> born
#
# Sentence: From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains.
# From            -> prep       -> exhibited
# an              -> det        -> age
# early           -> amod       -> age
# age             -> pobj       -> From
# ,               -> punct      -> exhibited
# Shivaji         -> nsubj      -> exhibited
# exhibited       -> ROOT       -> exhibited
# remarkable      -> amod       -> qualities
# leadership      -> compound   -> qualities
# qualities       -> dobj       -> exhibited
# ,               -> punct      -> exhibited
# forming         -> advcl      -> exhibited
# a               -> det        -> group
# group           -> dobj       -> forming
# of              -> prep       -> group
# loyal           -> amod       -> followers
# followers       -> pobj       -> of
# and             -> cc         -> forming
# honing          -> conj       -> forming
# his             -> poss       -> skills
# military        -> amod       -> skills
# skills          -> dobj       -> honing
# in              -> prep       -> honing
# the             -> det        -> terrain
# rugged          -> amod       -> terrain
# terrain         -> pobj       -> in
# of              -> prep       -> terrain
# the             -> det        -> mountains
# Sahyadri        -> compound   -> mountains
# mountains       -> pobj       -> of
# .               -> punct      -> exhibited
#
# Sentence: He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often oppressing the local population, which deeply disturbed him and fueled his desire to establish Swarajya, or self-rule for the Marathas.
# He              -> nsubj      -> grew
# grew            -> ROOT       -> grew
# up              -> prt        -> grew
# during          -> prep       -> grew
# a               -> det        -> time
# time            -> pobj       -> during
# when            -> advmod     -> vying
# the             -> det        -> Empire
# Mughal          -> compound   -> Empire
# Empire          -> nsubj      -> vying
# under           -> prep       -> Empire
# Emperor         -> compound   -> Aurangzeb
# Aurangzeb       -> pobj       -> under
# and             -> cc         -> Empire
# the             -> det        -> Sultanates
# Deccan          -> compound   -> Sultanates
# Sultanates      -> conj       -> Empire
# were            -> aux        -> vying
# vying           -> relcl      -> time
# for             -> prep       -> vying
# control         -> pobj       -> for
# ,               -> punct      -> grew
# often           -> advmod     -> oppressing
# oppressing      -> advcl      -> grew
# the             -> det        -> population
# local           -> amod       -> population
# population      -> dobj       -> oppressing
# ,               -> punct      -> population
# which           -> nsubj      -> disturbed
# deeply          -> advmod     -> disturbed
# disturbed       -> relcl      -> population
# him             -> dobj       -> disturbed
# and             -> cc         -> disturbed
# fueled          -> conj       -> disturbed
# his             -> poss       -> desire
# desire          -> dobj       -> fueled
# to              -> aux        -> establish
# establish       -> acl        -> desire
# Swarajya        -> dobj       -> establish
# ,               -> punct      -> Swarajya
# or              -> cc         -> Swarajya
# self            -> compound   -> rule
# -               -> punct      -> rule
# rule            -> conj       -> Swarajya
# for             -> prep       -> rule
# the             -> det        -> Marathas
# Marathas        -> pobj       -> for
# .               -> punct      -> grew
#
# Sentence: By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy.
# By              -> prep       -> captured
# the             -> det        -> age
# age             -> pobj       -> By
# of              -> prep       -> age
# 16              -> pobj       -> of
# ,               -> punct      -> captured
# Shivaji         -> nsubj      -> captured
# had             -> aux        -> captured
# captured        -> ROOT       -> captured
# his             -> poss       -> fort
# first           -> amod       -> fort
# fort            -> dobj       -> captured
# ,               -> punct      -> fort
# Torna           -> appos      -> fort
# ,               -> punct      -> fort
# using           -> advcl      -> captured
# guerrilla       -> compound   -> tactics
# warfare         -> compound   -> tactics
# tactics         -> dobj       -> using
# that            -> nsubj      -> become
# would           -> aux        -> become
# later           -> advmod     -> become
# become          -> relcl      -> tactics
# a               -> det        -> hallmark
# hallmark        -> attr       -> become
# of              -> prep       -> hallmark
# his             -> poss       -> strategy
# military        -> amod       -> strategy
# strategy        -> pobj       -> of
# .               -> punct      -> captured
#
# Sentence: As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India.
# As              -> mark       -> grew
# his             -> poss       -> conquests
# conquests       -> nsubj      -> grew
# grew            -> advcl      -> formed
# ,               -> punct      -> formed
# he              -> nsubj      -> formed
# formed          -> ROOT       -> formed
# alliances       -> dobj       -> formed
# with            -> prep       -> alliances
# local           -> amod       -> leaders
# leaders         -> pobj       -> with
# ,               -> punct      -> formed
# securing        -> advcl      -> formed
# key             -> amod       -> forts
# forts           -> dobj       -> securing
# like            -> prep       -> forts
# Raigad          -> pobj       -> like
# ,               -> punct      -> Raigad
# Kondana         -> conj       -> Raigad
# ,               -> punct      -> Kondana
# and             -> cc         -> Kondana
# Purandar        -> conj       -> Kondana
# ,               -> punct      -> securing
# establishing    -> conj       -> securing
# a               -> det        -> base
# solid           -> amod       -> base
# territorial     -> amod       -> base
# base            -> dobj       -> establishing
# in              -> prep       -> base
# western         -> amod       -> India
# India           -> pobj       -> in
# .               -> punct      -> formed
#
# Sentence: In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan.
# In              -> prep       -> faced
# 1659            -> pobj       -> In
# ,               -> punct      -> faced
# he              -> nsubj      -> faced
# faced           -> ccomp      -> was
# and             -> cc         -> faced
# defeated        -> conj       -> faced
# Afzal           -> compound   -> Khan
# Khan            -> dobj       -> defeated
# ,               -> punct      -> Khan
# a               -> det        -> general
# prominent       -> amod       -> general
# general         -> appos      -> Khan
# of              -> prep       -> general
# the             -> det        -> Sultanate
# Bijapur         -> compound   -> Sultanate
# Sultanate       -> pobj       -> of
# ,               -> punct      -> Khan
# solidifying     -> advcl      -> defeated
# his             -> poss       -> reputation
# reputation      -> dobj       -> solidifying
# as              -> prep       -> reputation
# a               -> det        -> leader
# brave           -> amod       -> leader
# and             -> cc         -> brave
# tactical        -> conj       -> brave
# leader          -> pobj       -> as
# ;               -> punct      -> was
# this            -> det        -> victory
# victory         -> nsubj      -> was
# was             -> ROOT       -> was
# crucial         -> acomp      -> was
# in              -> prep       -> was
# establishing    -> pcomp      -> in
# his             -> poss       -> control
# control         -> dobj       -> establishing
# over            -> prep       -> establishing
# much            -> pobj       -> over
# of              -> prep       -> much
# the             -> det        -> Deccan
# Deccan          -> pobj       -> of
# .               -> punct      -> was
#
# Sentence: Shivaji’s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolstered his legend.
# Shivaji         -> poss       -> raids
# ’s              -> case       -> Shivaji
# raids           -> nsubj      -> bolstered
# on              -> prep       -> raids
# Mughal          -> amod       -> territories
# territories     -> pobj       -> on
# and             -> cc         -> raids
# his             -> poss       -> escape
# escape          -> conj       -> raids
# from            -> prep       -> escape
# the             -> det        -> clutches
# clutches        -> pobj       -> from
# of              -> prep       -> clutches
# Aurangzeb       -> pobj       -> of
# in              -> prep       -> clutches
# Agra            -> pobj       -> in
# in              -> prep       -> escape
# 1666            -> pobj       -> in
# further         -> advmod     -> bolstered
# bolstered       -> ROOT       -> bolstered
# his             -> poss       -> legend
# legend          -> dobj       -> bolstered
# .               -> punct      -> bolstered
#
# Sentence: He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces.
# He              -> nsubj      -> realized
# realized        -> ROOT       -> realized
# that            -> mark       -> was
# a               -> det        -> navy
# powerful        -> amod       -> navy
# navy            -> nsubj      -> was
# was             -> ccomp      -> realized
# crucial         -> acomp      -> was
# to              -> aux        -> safeguard
# safeguard       -> xcomp      -> was
# his             -> poss       -> territories
# territories     -> dobj       -> safeguard
# from            -> prep       -> safeguard
# foreign         -> amod       -> invasions
# invasions       -> pobj       -> from
# ,               -> punct      -> was
# leading         -> advcl      -> was
# him             -> dobj       -> leading
# to              -> aux        -> develop
# develop         -> xcomp      -> leading
# one             -> dobj       -> develop
# of              -> prep       -> one
# the             -> det        -> forces
# earliest        -> amod       -> forces
# organized       -> amod       -> forces
# naval           -> amod       -> forces
# forces          -> pobj       -> of
# in              -> prep       -> forces
# India           -> pobj       -> in
# ,               -> punct      -> develop
# allowing        -> advcl      -> develop
# him             -> nsubj      -> secure
# to              -> aux        -> secure
# secure          -> ccomp      -> allowing
# coastal         -> amod       -> areas
# areas           -> dobj       -> secure
# against         -> prep       -> areas
# Portuguese      -> nmod       -> forces
# ,               -> punct      -> Portuguese
# British         -> conj       -> Portuguese
# ,               -> punct      -> British
# and             -> cc         -> British
# Siddis          -> compound   -> forces
# forces          -> pobj       -> against
# .               -> punct      -> realized
#
# Sentence: In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos.
# In              -> prep       -> crowned
# 1674            -> pobj       -> In
# ,               -> punct      -> crowned
# he              -> nsubj      -> crowned
# formally        -> advmod     -> crowned
# crowned         -> ROOT       -> crowned
# himself         -> dobj       -> crowned
# as              -> prep       -> crowned
# Chhatrapati     -> pobj       -> as
# at              -> prep       -> Chhatrapati
# Raigad          -> compound   -> Fort
# Fort            -> pobj       -> at
# ,               -> punct      -> crowned
# declaring       -> advcl      -> crowned
# his             -> poss       -> independence
# independence    -> dobj       -> declaring
# and             -> cc         -> declaring
# establishing    -> conj       -> declaring
# the             -> det        -> Empire
# Maratha         -> compound   -> Empire
# Empire          -> dobj       -> establishing
# ,               -> punct      -> declaring
# thus            -> advmod     -> becoming
# becoming        -> advcl      -> declaring
# the             -> det        -> king
# first           -> amod       -> king
# king            -> attr       -> becoming
# to              -> aux        -> establish
# establish       -> advcl      -> becoming
# Hindavi         -> compound   -> Swarajya
# Swarajya        -> dobj       -> establish
# ,               -> punct      -> Swarajya
# an              -> det        -> kingdom
# autonomous      -> amod       -> kingdom
# kingdom         -> appos      -> Swarajya
# with            -> prep       -> kingdom
# a               -> det        -> framework
# structured      -> amod       -> framework
# administrative  -> amod       -> framework
# framework       -> pobj       -> with
# rooted          -> acl        -> framework
# in              -> prep       -> rooted
# Indian          -> amod       -> ethos
# ethos           -> pobj       -> in
# .               -> punct      -> crowned
#
# Sentence: Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance.
# Shivaji         -> poss       -> system
# ’s              -> case       -> Shivaji
# administrative  -> amod       -> system
# system          -> nsubj      -> was
# was             -> ccomp      -> included
# highly          -> advmod     -> efficient
# efficient       -> acomp      -> was
# ,               -> punct      -> was
# and             -> cc         -> was
# he              -> nsubj      -> emphasized
# emphasized      -> conj       -> was
# the             -> det        -> welfare
# welfare         -> dobj       -> emphasized
# of              -> prep       -> welfare
# his             -> poss       -> people
# people          -> pobj       -> of
# ,               -> punct      -> emphasized
# setting         -> advcl      -> emphasized
# up              -> prt        -> setting
# systems         -> dobj       -> setting
# to              -> aux        -> reduce
# reduce          -> advcl      -> setting
# corruption      -> dobj       -> reduce
# and             -> cc         -> reduce
# create          -> conj       -> reduce
# a               -> det        -> structure
# fair            -> amod       -> structure
# tax             -> compound   -> structure
# structure       -> dobj       -> create
# ;               -> punct      -> included
# his             -> poss       -> Pradhan
# Ashta           -> compound   -> Pradhan
# Pradhan         -> nsubj      -> included
# (               -> punct      -> Pradhan
# Council         -> appos      -> Pradhan
# of              -> prep       -> Council
# Eight           -> compound   -> Ministers
# Ministers       -> pobj       -> of
# )               -> punct      -> Pradhan
# included        -> ROOT       -> included
# departments     -> dobj       -> included
# for             -> prep       -> departments
# finance         -> pobj       -> for
# ,               -> punct      -> finance
# internal        -> amod       -> affairs
# affairs         -> conj       -> finance
# ,               -> punct      -> affairs
# foreign         -> amod       -> policy
# policy          -> conj       -> affairs
# ,               -> punct      -> policy
# and             -> cc         -> policy
# military        -> conj       -> policy
# to              -> aux        -> ensure
# ensure          -> advcl      -> included
# smooth          -> amod       -> governance
# governance      -> dobj       -> ensure
# .               -> punct      -> included
#
# Sentence: Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites.
# Shivaji         -> nsubj      -> showed
# showed          -> ROOT       -> showed
# a               -> det        -> approach
# progressive     -> amod       -> approach
# approach        -> dobj       -> showed
# towards         -> prep       -> approach
# governance      -> pobj       -> towards
# ,               -> punct      -> showed
# promoting       -> advcl      -> showed
# religious       -> amod       -> tolerance
# tolerance       -> dobj       -> promoting
# and             -> cc         -> promoting
# respecting      -> conj       -> promoting
# the             -> det        -> diversity
# diversity       -> dobj       -> respecting
# within          -> prep       -> respecting
# his             -> poss       -> empire
# empire          -> pobj       -> within
# ,               -> punct      -> promoting
# even            -> advmod     -> appointing
# appointing      -> conj       -> promoting
# Muslims         -> dobj       -> appointing
# to              -> prep       -> appointing
# key             -> amod       -> positions
# positions       -> pobj       -> to
# in              -> prep       -> positions
# his             -> poss       -> administration
# administration  -> pobj       -> in
# and             -> cc         -> appointing
# banning         -> conj       -> appointing
# the             -> det        -> harassment
# harassment      -> dobj       -> banning
# of              -> prep       -> harassment
# women           -> pobj       -> of
# and             -> cc         -> harassment
# looting         -> conj       -> harassment
# of              -> prep       -> looting
# religious       -> amod       -> sites
# sites           -> pobj       -> of
# .               -> punct      -> showed
#
# Sentence: His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time.
# His             -> poss       -> respect
# respect         -> nsubj      -> inspired
# for             -> prep       -> respect
# women           -> pobj       -> for
# and             -> cc         -> women
# his             -> poss       -> advocacy
# advocacy        -> conj       -> women
# for             -> prep       -> advocacy
# justice         -> pobj       -> for
# inspired        -> ROOT       -> inspired
# trust           -> dobj       -> inspired
# and             -> cc         -> trust
# loyalty         -> conj       -> trust
# among           -> prep       -> trust
# his             -> poss       -> people
# people          -> pobj       -> among
# ,               -> punct      -> inspired
# making          -> advcl      -> inspired
# him             -> nsubj      -> ruler
# an              -> det        -> ruler
# ideal           -> amod       -> ruler
# ruler           -> ccomp      -> making
# for             -> prep       -> ruler
# his             -> poss       -> time
# time            -> pobj       -> for
# .               -> punct      -> inspired
#
# Sentence: Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses.
# Shivaji         -> compound   -> Maharaj
# Maharaj         -> poss       -> tactics
# ’s              -> case       -> Maharaj
# guerrilla       -> compound   -> tactics
# tactics         -> nsubj      -> became
# ,               -> punct      -> tactics
# known           -> acl        -> tactics
# as              -> prep       -> known
# “               -> punct      -> as
# Ganimi          -> compound   -> Kava
# Kava            -> pobj       -> as
# ,               -> punct      -> tactics
# ”               -> punct      -> tactics
# became          -> ROOT       -> became
# legendary       -> acomp      -> became
# and             -> cc         -> became
# enabled         -> conj       -> became
# him             -> dobj       -> enabled
# to              -> aux        -> outmaneuver
# outmaneuver     -> xcomp      -> enabled
# much            -> advmod     -> larger
# larger          -> amod       -> armies
# and             -> cc         -> larger
# better          -> advmod     -> equipped
# -               -> punct      -> equipped
# equipped        -> conj       -> larger
# armies          -> dobj       -> outmaneuver
# repeatedly      -> advmod     -> outmaneuver
# ,               -> punct      -> enabled
# allowing        -> advcl      -> enabled
# him             -> nsubj      -> expand
# to              -> aux        -> expand
# expand          -> ccomp      -> allowing
# his             -> poss       -> empire
# empire          -> dobj       -> expand
# while           -> mark       -> minimizing
# minimizing      -> advcl      -> expand
# losses          -> dobj       -> minimizing
# .               -> punct      -> became
#
# Sentence: As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India.
# As              -> mark       -> grew
# his             -> poss       -> fame
# fame            -> nsubj      -> grew
# grew            -> advcl      -> began
# ,               -> punct      -> began
# the             -> det        -> Empire
# Maratha         -> compound   -> Empire
# Empire          -> nsubj      -> began
# began           -> ROOT       -> began
# to              -> aux        -> influence
# influence       -> xcomp      -> began
# regions         -> dobj       -> influence
# far             -> advmod     -> beyond
# beyond          -> prep       -> influence
# Maharashtra     -> pobj       -> beyond
# ,               -> punct      -> influence
# with            -> prep       -> influence
# Maratha         -> compound   -> forces
# forces          -> nsubj      -> becoming
# eventually      -> advmod     -> becoming
# becoming        -> pcomp      -> with
# a               -> det        -> power
# significant     -> amod       -> power
# power           -> attr       -> becoming
# across          -> prep       -> power
# India           -> pobj       -> across
# .               -> punct      -> began
#
# Sentence: Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death.
# Shivaji         -> nsubj      -> passed
# passed          -> ROOT       -> passed
# away            -> prt        -> passed
# on              -> prep       -> passed
# April           -> pobj       -> on
# 3               -> nummod     -> April
# ,               -> punct      -> April
# 1680            -> nummod     -> April
# ,               -> punct      -> April
# at              -> prep       -> passed
# Raigad          -> compound   -> Fort
# Fort            -> pobj       -> at
# ,               -> punct      -> passed
# leaving         -> advcl      -> passed
# behind          -> advmod     -> leaving
# a               -> det        -> legacy
# powerful        -> amod       -> legacy
# legacy          -> dobj       -> leaving
# and             -> cc         -> legacy
# a               -> det        -> state
# well            -> advmod     -> organized
# -               -> punct      -> organized
# organized       -> amod       -> state
# state           -> conj       -> legacy
# that            -> nsubj      -> continued
# continued       -> relcl      -> state
# to              -> aux        -> expand
# expand          -> xcomp      -> continued
# after           -> prep       -> expand
# his             -> poss       -> death
# death           -> pobj       -> after
# .               -> punct      -> passed
#
# Sentence: His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endures in the form of the Maratha Empire’s contributions to India’s history and culture.
# His             -> poss       -> life
# life            -> nsubj      -> continue
# and             -> cc         -> life
# ideals          -> conj       -> life
# —               -> punct      -> life
# valor           -> appos      -> life
# ,               -> punct      -> valor
# respect         -> appos      -> life
# for             -> prep       -> respect
# all             -> det        -> faiths
# faiths          -> pobj       -> for
# ,               -> punct      -> respect
# and             -> cc         -> respect
# self            -> compound   -> rule
# -               -> punct      -> rule
# rule            -> conj       -> respect
# —               -> punct      -> continue
# continue        -> ROOT       -> continue
# to              -> aux        -> inspire
# inspire         -> xcomp      -> continue
# millions        -> dobj       -> inspire
# ,               -> punct      -> continue
# and             -> cc         -> continue
# his             -> poss       -> legacy
# legacy          -> nsubj      -> endures
# endures         -> conj       -> continue
# in              -> prep       -> endures
# the             -> det        -> form
# form            -> pobj       -> in
# of              -> prep       -> form
# the             -> det        -> Empire
# Maratha         -> compound   -> Empire
# Empire          -> poss       -> contributions
# ’s              -> case       -> Empire
# contributions   -> pobj       -> of
# to              -> prep       -> contributions
# India           -> poss       -> history
# ’s              -> case       -> India
# history         -> pobj       -> to
# and             -> cc         -> history
# culture         -> conj       -> history
# .               -> punct      -> endures
#
# Visualizing Dependency Tree for the First Sentence:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5c1550c4ddb34d708464331c62795fb1-0" class="displacy" width="6000" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Chhatrapati</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Shivaji</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Maharaj</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">born</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">February</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">19,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">1630,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Shivneri</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">Fort</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">Maharashtra,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">Shahaji</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Bhonsle,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">Maratha</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">general,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">Jijabai,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">who</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">deeply</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">influenced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">Shivaji</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">her</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">teachings</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">dharma,</tspan>
#     <tspan class="displac

# %%
import spacy
from spacy.matcher import PhraseMatcher, Matcher
nlp = spacy.load("en_core_web_sm")

doc = nlp(text)

# Task 1: Identify occurrences of the phrase "Maratha Empire"
matcher = PhraseMatcher(nlp.vocab)
phrase = nlp("Maratha Empire")
matcher.add("MarathaEmpire", [phrase])

matches = matcher(doc)
print("Occurrences of the phrase 'Maratha Empire':")
for match_id, start, end in matches:
    print(f"Match found at index: {start} - {end}, Phrase: '{doc[start:end]}'")

# Task 2: Use spaCy’s Matcher to find patterns where "Shivaji Maharaj" is mentioned with actions (verbs)
matcher_action = Matcher(nlp.vocab)
pattern = [{"LOWER": "shivaji"}, {"LOWER": "maharaj"}, {"POS": "VERB"}]
matcher_action.add("ShivajiActions", [pattern])

matches_action = matcher_action(doc)
print("\nPatterns where 'Shivaji Maharaj' is mentioned with actions (verbs):")
for match_id, start, end in matches_action:
    print(f"Match found at index: {start} - {end}, Phrase: '{doc[start:end]}'")
# Out:
# Occurrences of the phrase 'Maratha Empire':
# Match found at index: 313 - 315, Phrase: 'Maratha Empire'
# Match found at index: 507 - 509, Phrase: 'Maratha Empire'
# Match found at index: 591 - 593, Phrase: 'Maratha Empire'
#
# Patterns where 'Shivaji Maharaj' is mentioned with actions (verbs):

# %%
import spacy
from textblob import TextBlob
nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

# Task 1: Calculate the similarity between the first two sentences using spaCy
first_sentence = list(doc.sents)[0]
second_sentence = list(doc.sents)[1]

similarity_spacy = first_sentence.similarity(second_sentence)
print(f"Similarity between the first two sentences (spaCy): {similarity_spacy:.4f}")

# Task 2: Compute the similarity between sentences mentioning "Shivaji" and "Mughal Empire" using TextBlob
blob = TextBlob(text)

# Extract sentences mentioning "Shivaji" and "Mughal Empire"
shivaji_sentence = next((sentence for sentence in blob.sentences if "Shivaji" in sentence), None)
mughal_sentence = next((sentence for sentence in blob.sentences if "Mughal Empire" in sentence), None)

if shivaji_sentence and mughal_sentence:
    similarity_textblob = shivaji_sentence.sentiment.polarity * mughal_sentence.sentiment.polarity
    print(f"Similarity between sentences mentioning 'Shivaji' and 'Mughal Empire' (TextBlob): {similarity_textblob:.4f}")
else:
    print("One of the sentences does not exist.")
# Out:
# Similarity between the first two sentences (spaCy): 0.5162
# Similarity between sentences mentioning 'Shivaji' and 'Mughal Empire' (TextBlob): 0.0000
# <ipython-input-17-5a53f7b52ab3>:10: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Span.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similarity_spacy = first_sentence.similarity(second_sentence)

# %%
! pip install deep-translator
# Out:
# Collecting deep-translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from deep-translator) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from deep-translator) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2024.8.30)
# Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: deep-translator
# Successfully installed deep-translator-1.11.4

# %%
from deep_translator import GoogleTranslator

text = """Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice. From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains. He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often oppressing the local population, which deeply disturbed him and fueled his desire to establish Swarajya, or self-rule for the Marathas. By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy. As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India. In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan. Shivaji’s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolstered his legend. He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces. In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos. Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance. Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites. His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time. Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses. As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India. Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death. His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endures in the form of the Maratha Empire’s contributions to India’s history and culture."""

# Task 1: Translate the first paragraph into Hindi
try:
    translated_hindi = GoogleTranslator(source='auto', target='hi').translate(text)
    print("Translated text in Hindi:")
    print(translated_hindi)
except Exception as e:
    print(f"Error in translation to Hindi: {e}")

# Task 2: Translate the phrase "Hindavi Swarajya" into French
phrase = "Hindavi Swarajya"
try:
    translated_french = GoogleTranslator(source='auto', target='fr').translate(phrase)
    print("\nTranslated phrase in French:")
    print(translated_french)
except Exception as e:
    print(f"Error in translation to French: {e}")
# Out:
# Translated text in Hindi:
# छत्रपति शिवाजी महाराज का जन्म 19 फरवरी, 1630 को महाराष्ट्र के शिवनेरी किले में, मराठा सेनापति शाहजी भोंसले और जीजाबाई के घर हुआ था, जिन्होंने धर्म, बहादुरी और न्याय की अपनी शिक्षाओं से शिवाजी को गहराई से प्रभावित किया था। कम उम्र से ही, शिवाजी ने उल्लेखनीय नेतृत्व गुणों का प्रदर्शन किया, वफादार अनुयायियों का एक समूह बनाया और सह्याद्री पहाड़ों के बीहड़ इलाकों में अपने सैन्य कौशल को बढ़ाया। वह ऐसे समय में बड़ा हुआ जब सम्राट औरंगजेब और दक्कन सल्तनत के अधीन मुगल साम्राज्य नियंत्रण के लिए होड़ कर रहा था, अक्सर स्थानीय आबादी पर अत्याचार करता था, जिसने उसे बहुत परेशान किया और मराठों के लिए स्वराज्य, या स्व-शासन स्थापित करने की उसकी इच्छा को बढ़ावा दिया। 16 साल की उम्र तक, शिवाजी ने गुरिल्ला युद्ध रणनीति का उपयोग करके अपने पहले किले, तोरण पर कब्जा कर लिया था जैसे-जैसे उनकी विजय बढ़ती गई, उन्होंने स्थानीय नेताओं के साथ गठबंधन किया, रायगढ़, कोंडाना और पुरंदर जैसे प्रमुख किलों को सुरक्षित किया, पश्चिमी भारत में एक ठोस क्षेत्रीय आधार स्थापित किया। 1659 में, उन्होंने बीजापुर सल्तनत के एक प्रमुख सेनापति अफ़ज़ल खान का सामना किया और उसे हराया, जिससे एक बहादुर और सामरिक नेता के रूप में उनकी प्रतिष्ठा मजबूत हुई; यह जीत डेक्कन के अधिकांश हिस्से पर अपना नियंत्रण स्थापित करने में महत्वपूर्ण थी। मुगल क्षेत्रों पर शिवाजी के छापे और 1666 में आगरा में औरंगज़ेब के चंगुल से उनके भागने ने उनकी किंवदंती को और मजबूत किया। उन्होंने महसूस किया कि विदेशी आक्रमणों से अपने क्षेत्रों की रक्षा के लिए एक शक्तिशाली नौसेना महत्वपूर्ण थी, जिसके कारण उन्होंने भारत में सबसे शुरुआती संगठित नौसेना बलों में से एक विकसित किया, जिससे उन्हें पुर्तगाली, ब्रिटिश और सिद्दी सेनाओं के खिलाफ तटीय क्षेत्रों को सुरक्षित करने में मदद मिली। 1674 में, उन्होंने औपचारिक रूप से रायगढ़ किले में छत्रपति के रूप में खुद को ताज पहनाया, अपनी स्वतंत्रता की घोषणा की और मराठा साम्राज्य की स्थापना की, इस प्रकार वे हिंदवी स्वराज्य की स्थापना करने वाले पहले राजा बन गए, जो भारतीय लोकाचार में निहित एक संरचित प्रशासनिक ढांचे वाला एक स्वायत्त राज्य था। शिवाजी की प्रशासनिक व्यवस्था अत्यधिक कुशल थी, और उन्होंने अपने लोगों के कल्याण पर जोर दिया, भ्रष्टाचार को कम करने और एक निष्पक्ष कर संरचना बनाने के लिए सिस्टम स्थापित किए; उनके अष्ट प्रधान (आठ मंत्रियों की परिषद) में सुचारू शासन सुनिश्चित करने के लिए वित्त, आंतरिक मामले, विदेश नीति और सैन्य विभाग शामिल थे। शिवाजी ने शासन के प्रति एक प्रगतिशील दृष्टिकोण दिखाया, धार्मिक सहिष्णुता को बढ़ावा दिया और अपने साम्राज्य के भीतर विविधता का सम्मान किया, यहाँ तक कि मुसलमानों को अपने प्रशासन में प्रमुख पदों पर नियुक्त किया और महिलाओं के उत्पीड़न और धार्मिक स्थलों की लूट पर प्रतिबंध लगा दिया। महिलाओं के प्रति उनके सम्मान और न्याय के लिए उनकी वकालत ने उनके लोगों के बीच विश्वास और वफादारी को प्रेरित किया, जिससे वे अपने समय के लिए एक आदर्श शासक बन गए। शिवाजी महाराज की गुरिल्ला रणनीति, जिसे "गनीमी कावा" के रूप में जाना जाता है, प्रसिद्ध हो गई और उन्हें बार-बार बहुत बड़ी और बेहतर सुसज्जित सेनाओं को मात देने में सक्षम बनाया, जिससे उन्हें नुकसान को कम करते हुए अपने साम्राज्य का विस्तार करने में मदद मिली। जैसे-जैसे उनकी प्रसिद्धि बढ़ी, मराठा साम्राज्य ने महाराष्ट्र से परे क्षेत्रों को प्रभावित करना शुरू कर दिया, और मराठा सेना अंततः पूरे भारत में एक महत्वपूर्ण शक्ति बन गई। शिवाजी का निधन 3 अप्रैल, 1680 को रायगढ़ किले में हुआ था, वे अपने पीछे एक शक्तिशाली विरासत और एक सुव्यवस्थित राज्य छोड़ गए थे जो उनकी मृत्यु के बाद भी बढ़ता रहा। उनका जीवन और आदर्श - वीरता, सभी धर्मों के प्रति सम्मान और स्वशासन - लाखों लोगों को प्रेरित करते हैं, और उनकी विरासत भारत के इतिहास और संस्कृति में मराठा साम्राज्य के योगदान के रूप में कायम है।
#
# Translated phrase in French:
# Hindavi Swarajya

# %%
text = """Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice. From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains. He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often oppressing the local population, which deeply disturbed him and fueled his desire to establish Swarajya, or self-rule for the Marathas. By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy. As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India. In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan. Shivaji’s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolstered his legend. He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces. In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos. Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance. Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites. His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time. Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses. As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India. Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death. His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endures in the form of the Maratha Empire’s contributions to India’s history and culture."""

# Task 1: Extract keywords using NLTK's frequency distribution
nltk.download('punkt')
nltk.download('stopwords')

# Tokenize words and filter out stop words
stop_words = set(stopwords.words('english'))
words = word_tokenize(text.lower())
filtered_words = [word for word in words if word.isalnum() and word not in stop_words]

# Calculate frequency distribution
freq_dist = FreqDist(filtered_words)

# Extract common nouns and verbs
common_keywords = [word for word, freq in freq_dist.items() if freq > 1]
print("Keywords extracted using NLTK (common nouns and verbs):")
print(common_keywords)

# Task 2: Identify unique keywords using spaCy
nlp = spacy.load('en_core_web_sm')
doc = nlp(text)

# Extract unique keywords (nouns and proper nouns) filtering out stop words
unique_keywords_spacy = {token.text.lower() for token in doc if token.is_alpha and not token.is_stop and (token.pos_ in ['NOUN', 'PROPN'])}
print("\nUnique keywords extracted using spaCy:")
print(list(unique_keywords_spacy))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Keywords extracted using NLTK (common nouns and verbs):
# ['chhatrapati', 'shivaji', 'maharaj', 'fort', 'maharashtra', 'maratha', 'general', 'deeply', 'justice', 'age', 'military', 'grew', 'time', 'mughal', 'empire', 'aurangzeb', 'deccan', 'control', 'local', 'establish', 'swarajya', 'first', 'guerrilla', 'tactics', 'key', 'raigad', 'establishing', 'india', 'crucial', 'much', 'territories', 'powerful', 'foreign', 'forces', 'allowing', 'becoming', 'administrative', 'people', 'governance', 'religious', 'women', 'respect', 'expand', 'legacy']
#
# Unique keywords extracted using spaCy:
# ['hallmark', 'military', 'corruption', 'life', 'muslims', 'mountains', 'emperor', 'general', 'millions', 'justice', 'hindavi', 'bijapur', 'reputation', 'skills', 'siddis', 'faiths', 'kondana', 'ruler', 'welfare', 'affairs', 'ideals', 'february', 'age', 'escape', 'deccan', 'kava', 'sultanate', 'dharma', 'group', 'clutches', 'navy', 'tactics', 'tolerance', 'ganimi', 'trust', 'tax', 'ministers', 'sultanates', 'areas', 'system', 'base', 'torna', 'power', 'india', 'pradhan', 'warfare', 'legend', 'shahaji', 'governance', 'empire', 'population', 'bhonsle', 'shivaji', 'forts', 'victory', 'harassment', 'valor', 'council', 'state', 'sites', 'leadership', 'culture', 'invasions', 'administration', 'approach', 'respect', 'fort', 'armies', 'history', 'purandar', 'april', 'departments', 'regions', 'territories', 'people', 'women', 'king', 'raigad', 'form', 'finance', 'kingdom', 'structure', 'guerrilla', 'loyalty', 'systems', 'maratha', 'khan', 'agra', 'losses', 'desire', 'qualities', 'strategy', 'portuguese', 'sahyadri', 'afzal', 'alliances', 'mughal', 'followers', 'policy', 'framework', 'positions', 'death', 'chhatrapati', 'diversity', 'control', 'leader', 'rule', 'looting', 'aurangzeb', 'teachings', 'conquests', 'self', 'shivneri', 'independence', 'swarajya', 'advocacy', 'terrain', 'ethos', 'legacy', 'maharaj', 'marathas', 'forces', 'contributions', 'time', 'leaders', 'maharashtra', 'jijabai', 'bravery', 'raids', 'fame', 'ashta']

# %%
from textblob import TextBlob
import matplotlib.pyplot as plt

blob = TextBlob(text)
sentences = blob.sentences

# Calculate sentiment polarity for each sentence
polarities = [sentence.sentiment.polarity for sentence in sentences]

# Plotting the sentiment polarity distribution
plt.figure(figsize=(10, 6))
plt.hist(polarities, bins=20, alpha=0.7, color='blue', edgecolor='black')
plt.title('Sentiment Polarity Distribution')
plt.xlabel('Sentiment Polarity')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# Identify the most positive and most negative sentences
most_positive = max(sentences, key=lambda s: s.sentiment.polarity)
most_negative = min(sentences, key=lambda s: s.sentiment.polarity)

print("Most Positive Sentence:")
print(most_positive)
print("Sentiment Polarity:", most_positive.sentiment.polarity)

print("\nMost Negative Sentence:")
print(most_negative)
print("Sentiment Polarity:", most_negative.sentiment.polarity)
# Out:
# Most Positive Sentence:
# His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time.
# Sentiment Polarity: 0.9
#
# Most Negative Sentence:
# As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India.
# Sentiment Polarity: -0.16

# %%
import spacy
import re
nlp = spacy.load('en_core_web_sm')
doc = nlp(text)

# Extract dates using spaCy's named entity recognition
dates = [ent.text for ent in doc.ents if ent.label_ == 'DATE']

print("Extracted Dates:")
print(dates)

# Regex to find sentences related to specific years (1674, 1680)
years = ['1674', '1680']
event_sentences = []

sentences = [sent.text for sent in doc.sents]

for sentence in sentences:
    for year in years:
        if year in sentence:
            event_sentences.append(sentence)
            break

print("\nSentences related to specific years:")
for event in event_sentences:
    print(event)
# Out:
# Extracted Dates:
# ['February 19, 1630', 'the age of 16', '1659', '1666', '1674', 'April 3, 1680']
#
# Sentences related to specific years:
# In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos.
# Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death.

# %%
from textblob import Word
from nltk.corpus import wordnet as wn
import nltk
nltk.download('wordnet')
synonym_words = ["bravery", "justice", "valor"]
antonym_words = ["oppression", "invasion"]

# Find synonyms using TextBlob
print("Synonyms:")
for word in synonym_words:
    synonyms = Word(word).synsets
    synonym_list = set()
    for syn in synonyms:
        for lemma in syn.lemmas():
            synonym_list.add(lemma.name())
    print(f"{word.capitalize()}: {', '.join(synonym_list)}")

# Find antonyms using NLTK's WordNet
print("\nAntonyms:")
for word in antonym_words:
    antonyms = []
    for syn in wn.synsets(word):
        for lemma in syn.lemmas():
            if lemma.antonyms():
                antonyms.extend(lemma.antonyms())
    antonym_list = set(ant.name() for ant in antonyms)
    print(f"{word.capitalize()}: {', '.join(antonym_list)}")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Synonyms:
# Bravery: fearlessness, bravery, braveness, courage, courageousness
# Justice: Department_of_Justice, justness, Justice_Department, jurist, judge, Justice, DoJ, justice
# Valor: valour, valor, valiance, valiancy, heroism, valorousness, gallantry
#
# Antonyms:
# Oppression:
# Invasion:

# %%
from textblob import TextBlob

text_with_errors = text.replace("Maharashtra", "Maharashta") \
                        .replace("influenced", "influance") \
                        .replace("strategies", "stratgies") \
                        .replace("territories", "teritories") \
                        .replace("legendary", "legandary")

# Create a TextBlob object
blob_with_errors = TextBlob(text_with_errors)

# Identify words with potential spelling errors
potential_errors = [word for word in blob_with_errors.words if word != word.correct()]

# Correct spelling errors
corrected_text = str(blob_with_errors.correct())

# Output the results
print("Text with Errors:")
print(text_with_errors)
print("\nCorrected Text:")
print(corrected_text)
print("\nWords with Potential Spelling Errors:")
print(potential_errors)
# Out:
# Text with Errors:
# Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashta, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influance Shivaji with her teachings on dharma, bravery, and justice. From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains. He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often oppressing the local population, which deeply disturbed him and fueled his desire to establish Swarajya, or self-rule for the Marathas. By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy. As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India. In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan. Shivaji’s raids on Mughal teritories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolstered his legend. He realized that a powerful navy was crucial to safeguard his teritories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces. In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos. Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance. Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites. His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time. Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legandary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses. As his fame grew, the Maratha Empire began to influence regions far beyond Maharashta, with Maratha forces eventually becoming a significant power across India. Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death. His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endures in the form of the Maratha Empire’s contributions to India’s history and culture.
#
# Corrected Text:
# Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Sort in Maharashta, to Shahaji Bhonsle, a Martha general, and Jijabai, who deeply influence Shivaji with her teachings on harm, bravery, and justice. From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and hoping his military skill in the rugged terrain of the Sahyadri mountains. He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often pressing the local population, which deeply disturbed him and field his desire to establish Swarajya, or self-rule for the Marathas. By the age of 16, Shivaji had captured his first fort, Worn, using guerrilla warfare tactics that would later become a hallmark of his military strategy. Is his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Montana, and Purandar, establishing a solid territorial base in western India. In 1659, he faced and defeated Foal Than, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan. Shivaji’s maids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further fostered his legend. He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Yiddish forces. In 1674, he formally crowned himself as Chhatrapati at Raigad Sort, declaring his independence and establishing the Martha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structures administrative framework rooted in Indian this. Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Sta Pradhan (Council of Right Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance. Shivaji showed a progressive approach towards governance, promoting religious tolerable and respecting the diversity within his empire, even pointing Muslims to key positions in his administration and banking the harassment of women and looting of religious sites. His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time. Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Cava,” became legandary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses. Is his fame grew, the Martha Empire began to influence regions far beyond Maharashta, with Martha forces eventually becoming a significant power across India. Shivaji passed away on April 3, 1680, at Raigad Sort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death. His life and ideals—valor, respect for all faith, and self-rule—continue to inspire millions, and his legacy endure in the form of the Martha Empire’s contributions to India’s history and culture.
#
# Words with Potential Spelling Errors:
# ['Fort', 'Maratha', 'influance', 'dharma', 'honing', 'skills', 'oppressing', 'fueled', 'Torna', 'As', 'Kondana', 'Afzal', 'Khan', 'raids', 'teritories', 'bolstered', 'teritories', 'Siddis', 'Fort', 'Maratha', 'structured', 'ethos', 'Ashta', 'Eight', 'tolerance', 'appointing', 'banning', 'Kava', 'As', 'Maratha', 'Maratha', 'Fort', 'faiths', 'endures', 'Maratha']

# %%
import spacy

# Load the spaCy English model
nlp = spacy.load('en_core_web_sm')
doc = nlp(text)

# Function to extract SVO triples
def extract_svo(doc):
    svos = []
    for sent in doc.sents:
        for token in sent:
            if token.dep_ in ("nsubj", "nsubjpass") and token.text.lower() == "shivaji":
                verb = [child for child in token.children if child.dep_ == "ROOT"]
                if verb:
                    obj = [child for child in verb[0].children if child.dep_ in ("dobj", "pobj")]
                    if obj:
                        svos.append((token.text, verb[0].text, obj[0].text))
    return svos

# Extract SVO triples
svo_triples = extract_svo(doc)

print("Subject-Verb-Object Triples where 'Shivaji' is the subject:")
if svo_triples:
    for subject, verb, obj in svo_triples:
        print(f"Subject: {subject}, Verb: {verb}, Object: {obj}")
else:
    print("No SVO triples found where 'Shivaji' is the subject.")
# Out:
# Subject-Verb-Object Triples where 'Shivaji' is the subject:
# No SVO triples found where 'Shivaji' is the subject.

# %%
# !pip install textblob nltk gensim
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (7.0.5)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim) (1.16.0)

# %%
# !pip install sumy
# Out:
# Collecting sumy
#   Downloading sumy-0.11.0-py2.py3-none-any.whl.metadata (7.5 kB)
# Collecting docopt<0.7,>=0.6.1 (from sumy)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting breadability>=0.1.20 (from sumy)
#   Downloading breadability-0.1.20.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from sumy) (2.32.3)
# Collecting pycountry>=18.2.23 (from sumy)
#   Downloading pycountry-24.6.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: nltk>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from sumy) (3.8.1)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from breadability>=0.1.20->sumy) (5.2.0)
# Requirement already satisfied: lxml>=2.0 in /usr/local/lib/python3.10/dist-packages (from breadability>=0.1.20->sumy) (4.9.4)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.0.2->sumy) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.0.2->sumy) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.0.2->sumy) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.0.2->sumy) (4.66.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.7.0->sumy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.7.0->sumy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.7.0->sumy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.7.0->sumy) (2024.8.30)
# Downloading sumy-0.11.0-py2.py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.3/97.3 kB 5.4 MB/s eta 0:00:00
# Downloading pycountry-24.6.1-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 54.7 MB/s eta 0:00:00
# Building wheels for collected packages: breadability, docopt
#   Building wheel for breadability (setup.py) ... done
#   Created wheel for breadability: filename=breadability-0.1.20-py2.py3-none-any.whl size=21692 sha256=c19796b34254783a9601100360009a373fc5663c6163af7a0af47b3ab12cf097
#   Stored in directory: /root/.cache/pip/wheels/64/22/90/b84fcc30e16598db20a0d41340616dbf9b1e82bbcc627b0b33
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=65d75637975bf5c9dee1a7162ecddb3b884500233814b9adbcca362265aac11e
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built breadability docopt
# Installing collected packages: docopt, pycountry, breadability, sumy
# Successfully installed breadability-0.1.20 docopt-0.6.2 pycountry-24.6.1 sumy-0.11.0

# %%
from textblob import TextBlob
from nltk.tokenize import sent_tokenize
from nltk import download
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lsa import LsaSummarizer

download('punkt')

# Summarizing using TextBlob
blob = TextBlob(text)
sentences = blob.sentences
key_sentences = sorted(sentences, key=lambda x: x.sentiment.polarity, reverse=True)[:3]
textblob_summary = ' '.join([str(sentence) for sentence in key_sentences])

print("TextBlob Summary:")
print(textblob_summary)

# Summarizing using Sumy
parser = PlaintextParser.from_string(text, Tokenizer("english"))
summarizer = LsaSummarizer()
sumy_summary = summarizer(parser.document, 3)

print("\nSumy Summary:")
for sentence in sumy_summary:
    print(sentence)
# Out:
# TextBlob Summary:
# His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time. Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses. In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos.
#
# Sumy Summary:
# As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India.
# In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan.
# In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
